# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно сохрани в нем заголовок "Комментарий студента" в каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента 2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).

# %% [markdown]
# # Прогноз температуры сплава - металлургический комбинат «Стальная птица»

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# Чтобы оптимизировать производственные расходы, металлургический комбинат «Стальная птица» решил уменьшить потребление электроэнергии на этапе обработки стали. Для этого комбинату нужно контролировать температуру сплава. Нужно построить модель, которая будет её предсказывать. Заказчик хочет использовать разработанную модель для имитации технологического процесса.

# %% [markdown]
# **Цель проекта** - на основе представленных данных построить модель, которая будет температуру сплава предсказывать. Данная модель позволит снизить затраты на электричество, обслуживание и ремонты.

# %% [markdown]
# **Описание этапа обработки**
#
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (этот процесс — десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (от англ. tribe — «масса»).
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (от англ. slab — «плита»).

# %% [markdown]
# **Описание данных**
#
# Данные состоят из нескольких файлов, полученных из разных источников:
# - data_arc_new.csv — данные об электродах;
# - data_bulk_new.csv — данные о подаче сыпучих материалов (объём);
# - data_bulk_time_new.csv — данные о подаче сыпучих материалов (время);
# - data_gas_new.csv — данные о продувке сплава газом;
# - data_temp_new.csv — результаты измерения температуры;
# - data_wire_new.csv — данные о проволочных материалах (объём);
# - data_wire_time_new.csv — данные о проволочных материалах (время).
#
# Файл data_arc_new.csv
# - key — номер партии;
# - Начало нагрева дугой — время начала нагрева;
# - Конец нагрева дугой — время окончания нагрева;
# - Активная мощность — значение активной мощности;
# - Реактивная мощность — значение реактивной мощности.
#
# Файл data_bulk_new.csv
# - key — номер партии;
# - Bulk 1 … Bulk 15 — объём подаваемого материала.
#
# Файл data_bulk_time_new.csv
# - key — номер партии;
# - Bulk 1 … Bulk 15 — время подачи материала.
#
# Файл data_gas_new.csv
# - key — номер партии;
# - Газ 1 — объём подаваемого газа.
#
# Файл data_temp_new.csv
# - key — номер партии;
# - Время замера — время замера;
# - Температура — значение температуры.
#
# Файл data_wire_new.csv
# - key — номер партии;
# - Wire 1 … Wire 9 — объём подаваемых проволочных материалов.
#
# Файл data_wire_time_new.csv
# - key — номер партии;
# - Wire 1 … Wire 9 — время подачи проволочных материалов.

# %% [markdown]
# **План работы**
#
# Шаг 1. Загрузка данных
# Загрузите данные и выполните их первичный осмотр.
#
# Шаг 2. Исследовательский анализ и предобработка данных
# Выполните исследовательский анализ каждого датафрейма и при необходимости выполните предобработку. Сделайте выводы об имеющихся признаках: понадобятся ли они для обучения моделей.
#
# Шаг 3. Объединение данных
# Объедините выбранные вами признаки в один датафрейм по ключу.
#
# Шаг 4. Исследовательский анализ и предобработка данных объединённого датафрейма
# Выполните исследовательский анализ объединённого датафрейма, визуализируйте распределения признаков и при необходимости выполните предобработку. Проведите корреляционный анализ. Напоминаем, что вы можете использовать не только имеющиеся признаки, но и генерировать новые.
#
# Шаг 5. Подготовка данных
# Выполните подготовку данных для обучения модели. Разделите данные на две выборки, при масштабировании и кодировании учитывайте особенности данных и моделей.
#
# Шаг 6. Обучение моделей машинного обучения
# Обучите как минимум две модели. Хотя бы для одной из них подберите как минимум два гиперпараметра.
#
# Шаг 7. Выбор лучшей модели
# Выберите лучшую модель и проверьте её качество на тестовой выборке.
#
# Шаг 8. Общий вывод и рекомендации заказчику
# Сделайте общий вывод о проделанной работе: опишите основные этапы работы, полученные результаты и дайте рекомендации для бизнеса.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %%
# !pip install -U numpy pandas matplotlib seaborn scikit-learn lightgbm -q

# %%
import time
start_time = time.time()

# %%
# работа с данными
import pandas as pd
import numpy as np

# исследовательский анализ
import matplotlib.pyplot as plt
import seaborn as sns
# import phik

# работа с выборками
from sklearn.model_selection import train_test_split

# работа с обучением моделей
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import Ridge
from lightgbm import LGBMRegressor
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# Константы
RANDOM_STATE = 130125

# %% [markdown]
# ### Загрузка данных

# %%
data_arc = pd.read_csv('/datasets/data_arc_new.csv', parse_dates=['Начало нагрева дугой', 'Конец нагрева дугой'])
data_bulk = pd.read_csv('/datasets/data_bulk_new.csv')
data_bulk_time = pd.read_csv('/datasets/data_bulk_time_new.csv', parse_dates=['Bulk 1', 'Bulk 2', 'Bulk 3', 'Bulk 4', 'Bulk 5',
                                                                  'Bulk 6', 'Bulk 7', 'Bulk 8', 'Bulk 9', 'Bulk 10',
                                                                  'Bulk 11', 'Bulk 12', 'Bulk 13', 'Bulk 14', 'Bulk 15'])
data_gas = pd.read_csv('/datasets/data_gas_new.csv')
data_temp = pd.read_csv('/datasets/data_temp_new.csv', parse_dates=['Время замера'])
data_wire = pd.read_csv('/datasets/data_wire_new.csv')
data_wire_time = pd.read_csv('/datasets/data_wire_time_new.csv', parse_dates=['Wire 1', 'Wire 2', 'Wire 3', 'Wire 4', 'Wire 5',
                                                                              'Wire 6', 'Wire 7', 'Wire 8', 'Wire 9'])

# %%
display(data_arc.head(10))
data_arc.info()
# Out:
#    key Начало нагрева дугой Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37           0.867133
# 5    2  2019-05-03 11:34:14 2019-05-03 11:36:31           0.381124
# 6    2  2019-05-03 11:38:50 2019-05-03 11:44:28           0.261665
# 7    2  2019-05-03 11:46:19 2019-05-03 11:48:25           0.710297
# 8    2  2019-05-03 11:49:48 2019-05-03 11:53:18           0.786322
# 9    3  2019-05-03 12:06:54 2019-05-03 12:11:34           1.101678
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691
# 5             0.220351
# 6             0.205527
# 7             0.484962
# ...

# %%
display(data_bulk.head(10))
data_bulk.info()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
# 5    6     NaN     NaN     NaN   117.0     NaN     NaN     NaN     NaN
# 6    7     NaN     NaN     NaN   117.0     NaN     NaN     NaN     NaN
# 7    8     NaN     NaN     NaN    99.0     NaN     NaN     NaN     NaN
# 8    9     NaN     NaN     NaN   117.0     NaN     NaN     NaN     NaN
# 9   10     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# ...

# %%
display(data_bulk_time.head(10))
data_bulk_time.info()
# Out:
#    key Bulk 1 Bulk 2 Bulk 3              Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaT    NaT    NaT 2019-05-03 11:28:48    NaT    NaT    NaT    NaT
# 1    2    NaT    NaT    NaT 2019-05-03 11:36:50    NaT    NaT    NaT    NaT
# 2    3    NaT    NaT    NaT 2019-05-03 12:32:39    NaT    NaT    NaT    NaT
# 3    4    NaT    NaT    NaT 2019-05-03 12:43:22    NaT    NaT    NaT    NaT
# 4    5    NaT    NaT    NaT 2019-05-03 13:30:47    NaT    NaT    NaT    NaT
# 5    6    NaT    NaT    NaT 2019-05-03 13:57:27    NaT    NaT    NaT    NaT
# 6    7    NaT    NaT    NaT 2019-05-03 14:18:58    NaT    NaT    NaT    NaT
# 7    8    NaT    NaT    NaT 2019-05-03 15:17:58    NaT    NaT    NaT    NaT
# 8    9    NaT    NaT    NaT 2019-05-03 16:03:08    NaT    NaT    NaT    NaT
# 9   10    NaT    NaT    NaT                 NaT    NaT    NaT    NaT    NaT
#
#   Bulk 9 Bulk 10 Bulk 11             Bulk 12 Bulk 13             Bulk 14  \
# ...

# %%
display(data_gas.head(10))
data_gas.info()
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
# 5    6  11.273392
# 6    7   9.836267
# 7    8  15.171553
# 8    9   8.216623
# 9   10   6.529891
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
display(data_temp.head(10))
data_temp.info()
# Out:
#    key        Время замера  Температура
# 0    1 2019-05-03 11:02:04       1571.0
# 1    1 2019-05-03 11:07:18       1604.0
# 2    1 2019-05-03 11:11:34       1618.0
# 3    1 2019-05-03 11:18:04       1601.0
# 4    1 2019-05-03 11:25:59       1606.0
# 5    1 2019-05-03 11:30:38       1613.0
# 6    2 2019-05-03 11:34:04       1581.0
# 7    2 2019-05-03 11:38:40       1577.0
# 8    2 2019-05-03 11:46:09       1589.0
# 9    2 2019-05-03 11:49:38       1604.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  datetime64[ns]
#  2   Температура   14665 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 424.2 KB

# %%
display(data_wire.head(10))
data_wire.info()
# Out:
#    key      Wire 1     Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1   60.059998        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2   96.052315        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3   91.160157        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4   89.063515        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5   89.238236   9.114560     NaN     NaN     NaN     NaN     NaN     NaN
# 5    6   99.109917   9.114560     NaN     NaN     NaN     NaN     NaN     NaN
# 6    7   98.061600        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7    8  155.282394        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8    9  113.393279   9.143681     NaN     NaN     NaN     NaN     NaN     NaN
# 9   10   81.244796  12.376000     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# ...

# %%
display(data_wire_time.head(10))
data_wire_time.info()
# Out:
#    key              Wire 1              Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1 2019-05-03 11:06:19                 NaT    NaT    NaT    NaT    NaT
# 1    2 2019-05-03 11:36:50                 NaT    NaT    NaT    NaT    NaT
# 2    3 2019-05-03 12:11:46                 NaT    NaT    NaT    NaT    NaT
# 3    4 2019-05-03 12:43:22                 NaT    NaT    NaT    NaT    NaT
# 4    5 2019-05-03 13:20:44 2019-05-03 13:15:34    NaT    NaT    NaT    NaT
# 5    6 2019-05-03 13:57:27 2019-05-03 13:48:52    NaT    NaT    NaT    NaT
# 6    7 2019-05-03 14:18:58                 NaT    NaT    NaT    NaT    NaT
# 7    8 2019-05-03 15:01:30                 NaT    NaT    NaT    NaT    NaT
# 8    9 2019-05-03 15:45:44 2019-05-03 15:39:37    NaT    NaT    NaT    NaT
# 9   10 2019-05-03 16:27:00 2019-05-03 16:22:36    NaT    NaT    NaT    NaT
#
#   Wire 7 Wire 8 Wire 9
# 0    NaT    NaT    NaT
# 1    NaT    NaT    NaT
# 2    NaT    NaT    NaT
# 3    NaT    NaT    NaT
# ...

# %% [markdown]
# Все данные успешно загружены.

# %% [markdown]
# ### Исследовательский анализ и предобработка данных

# %%
# Функция для построения распределения числовых столбцов
def plot_numerical_distribution(df, columns):
    '''
    Выводит распределение данных указанного столбца в виде гистограммы и боксплот
    
    Параметры:
    - df: датафрейм
    - columns: выбранный столбец для вывода распределения
    '''
    for col in columns:
        # Создаем фигуру с двумя графиками
        fig, axes = plt.subplots(2, 1, figsize=(8, 5), gridspec_kw={'height_ratios': [3, 1]}, constrained_layout=True)
        
        # Гистограмма распределения
        sns.histplot(df[col].dropna(), bins=30, kde=False, ax=axes[0], color='blue', edgecolor='black')
        axes[0].set_title(f'Распределение {col}', fontsize=12, fontweight='bold')
        axes[0].set_xlabel(None)
        axes[0].set_ylabel('Частота', fontsize=10)
        axes[0].grid(axis='y', linestyle='--', alpha=0.5)
        
        # Диаграмма размаха (боксплот)
        sns.boxplot(x=df[col].dropna(), ax=axes[1], color='blue')
        axes[1].set_xlabel(col, fontsize=10)
        
        # Отображение графиков
        plt.show()
        
# Функция для проверки, есть ли добавления до первого замера или после последнего
def check_timing(row, time_columns, first_measurement_col, last_measurement_col):
    '''
    Проверяет, есть ли добавления материалов до первого замера или после последнего замера.

    Параметры:
    - row: строка датафрейма.
    - time_columns: список столбцов с временем добавления материалов.
    - first_measurement_col: название столбца с временем первого замера.
    - last_measurement_col: название столбца с временем последнего замера.

    Возвращает:
    - True, если есть недопустимые добавления, иначе False.
    '''
    for col in time_columns:
        material_time = row[col]
        if pd.notna(material_time):
            if material_time < row[first_measurement_col]:
                return True
            if material_time > row[last_measurement_col]:
                return True
    return False

# %% [markdown]
# #### data_temp — результаты измерения температуры

# %%
# Переименование столбцов 
rename_dict = {
    'Время замера': 'measurement_time',
    'Температура': 'temp'
} 

data_temp.rename(columns=rename_dict, inplace=True)

# %%
display(data_temp.head())
data_temp.info()
# Out:
#    key    measurement_time    temp
# 0    1 2019-05-03 11:02:04  1571.0
# 1    1 2019-05-03 11:07:18  1604.0
# 2    1 2019-05-03 11:11:34  1618.0
# 3    1 2019-05-03 11:18:04  1601.0
# 4    1 2019-05-03 11:25:59  1606.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   key               18092 non-null  int64
#  1   measurement_time  18092 non-null  datetime64[ns]
#  2   temp              14665 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 424.2 KB

# %%
# Анализ распределения признаков
plot_numerical_distribution(data_temp, ['temp'])

# %% [markdown]
# Как видим из распределения, есть аномальные низкие значения около 1200 градусов. Удалим данные ниже температуры плавления - 1500 градусов.

# %%
# Удаление значений температуры ниже 1500
data_temp = data_temp[data_temp['temp'] >= 1500]

# Удаление ключей с только одним значением температуры
keys_with_multiple_temps = data_temp['key'].value_counts()[data_temp['key'].value_counts() > 1].index
data_temp = data_temp[data_temp['key'].isin(keys_with_multiple_temps)]

# Проверка распределения после удаления
plot_numerical_distribution(data_temp, ['temp'])
display(data_temp.describe())
data_temp.info()
# Out:
#                 key               measurement_time          temp
# count  13920.000000                          13920  13920.000000
# mean    1243.619181  2019-06-20 17:55:38.043175424   1590.911494
# min        1.000000            2019-05-03 11:02:04   1515.000000
# 25%      624.000000            2019-05-27 00:22:43   1580.000000
# 50%     1246.000000            2019-06-19 13:43:01   1590.000000
# 75%     1870.000000            2019-07-11 20:13:28   1599.000000
# max     2499.000000            2019-08-10 13:58:58   1705.000000
# std      719.133465                            NaN     18.774355
# <class 'pandas.core.frame.DataFrame'>
# Index: 13920 entries, 0 to 13925
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   key               13920 non-null  int64
#  1   measurement_time  13920 non-null  datetime64[ns]
#  2   temp              13920 non-null  float64
# ...

# %%
# Агрегация данных
temp_summary = data_temp.groupby('key').agg(
    temp_start=('temp', 'first'),  # Первое значение температуры
    temp_end=('temp', 'last'),     # Последнее значение температуры
    first_temp_measurement=('measurement_time', 'min'),  # Первое время замера
    last_temp_measurement=('measurement_time', 'max')    # Последнее время замера
).reset_index()

# Добавляем время между замерами температуры (в минутах)
temp_summary['temp_measurement_duration'] = (
    temp_summary['last_temp_measurement'] - temp_summary['first_temp_measurement']
).dt.total_seconds() / 60  # В минутах

# Анализ распределения признаков в новом датафрейме
plot_numerical_distribution(temp_summary, ['temp_start', 'temp_end', 'temp_measurement_duration'])
display(temp_summary.head())
display(temp_summary.describe())
temp_summary.info()
# Out:
#    key  temp_start  temp_end first_temp_measurement last_temp_measurement  \
# 0    1      1571.0    1613.0    2019-05-03 11:02:04   2019-05-03 11:30:38
# 1    2      1581.0    1602.0    2019-05-03 11:34:04   2019-05-03 11:55:09
# 2    3      1596.0    1599.0    2019-05-03 12:06:44   2019-05-03 12:35:57
# 3    4      1601.0    1625.0    2019-05-03 12:39:27   2019-05-03 12:59:47
# 4    5      1576.0    1602.0    2019-05-03 13:11:03   2019-05-03 13:36:39
#
#    temp_measurement_duration
# 0                  28.566667
# 1                  21.083333
# 2                  29.216667
# 3                  20.333333
# 4                  25.600000
#                key   temp_start     temp_end         first_temp_measurement  \
# count  2475.000000  2475.000000  2475.000000                           2475
# mean   1250.787071  1589.029899  1595.336162  2019-06-21 00:12:27.429899008
# min       1.000000  1519.000000  1541.000000            2019-05-03 11:02:04
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Целевой признак выбран корректно

# %%
invalid_duration = temp_summary[temp_summary['temp_measurement_duration'] <=0]['key'].count()
print("Количество строк с некорректным временем: ", invalid_duration)
# Out:
# Количество строк с некорректным временем:  0

# %% [markdown]
# Распределение `temp_start` близко к нормальному с небольшой асимметрией в сторону высоких температур. Основная масса значений лежит в диапазоне от 1572°C до 1605°C.
#
# Распределение `temp_end` более узкое, чем у `temp_start`, с меньшим стандартным отклонением. Большинство значений сосредоточено в диапазоне от 1587°C до 1599°C. Хвост в сторону высоких температур (до 1700°C) короче.
#
# Узкое распределение `temp_end` с меньшим стандартным отклонением указывает на то, что температурные параметры к концу процесса стандартизированы и строго контролируются. Это ожидаемо, так как конечная температура — важный параметр для достижения требуемого качества стали.
#
# В `temp_start` есть выбросы в диапазоне более высоких температур (ближе к 1679°C), которые могут указывать на нестандартные партии или процессы. В `temp_end` хвост распределения ограничен (до 1700°C), но стоит проверить партии, которые имеют температуру выше 1600°C, на предмет соответствия технологическим нормам.
#
# Время между замерами первой и последней температуры сосредоточено в интервале от 0 до 500 минут. Положительная асимметрия распределения (хвост вправо) указывает на наличие некоторых замеров, для которых промежуток времени был значительно больше среднего.

# %% [markdown]
# #### data_arc - данные об электродах

# %%
# Переименование столбцов 
rename_dict = {
    'Начало нагрева дугой': 'start_heating_arc',
    'Конец нагрева дугой': 'end_heating_arc',
    'Активная мощность': 'active_power',
    'Реактивная мощность': 'reactive_power'
} 

data_arc.rename(columns=rename_dict, inplace=True)

# %%
display(data_arc.head())
data_arc.info()
# Out:
#    key   start_heating_arc     end_heating_arc  active_power  reactive_power
# 0    1 2019-05-03 11:02:14 2019-05-03 11:06:02      0.305130        0.211253
# 1    1 2019-05-03 11:07:28 2019-05-03 11:10:33      0.765658        0.477438
# 2    1 2019-05-03 11:11:44 2019-05-03 11:14:36      0.580313        0.430460
# 3    1 2019-05-03 11:18:14 2019-05-03 11:24:19      0.518496        0.379979
# 4    1 2019-05-03 11:26:09 2019-05-03 11:28:37      0.867133        0.643691
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                14876 non-null  int64
#  1   start_heating_arc  14876 non-null  datetime64[ns]
#  2   end_heating_arc    14876 non-null  datetime64[ns]
#  3   active_power       14876 non-null  float64
#  4   reactive_power     14876 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(1)
# ...

# %%
# Анализ распределения признаков
numerical_cols = ['active_power', 'reactive_power']
plot_numerical_distribution(data_arc, numerical_cols)

# %%
# Находим ключи, где reactive_power < 0 и удаляем все строки с этими ключами
invalid_keys = data_arc[data_arc['reactive_power'] < 0]['key'].unique()
data_arc = data_arc[~data_arc['key'].isin(invalid_keys)]

# Проверка распределения после удаления
plot_numerical_distribution(data_arc, numerical_cols)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что обработано наблюдение с отрицательной реактивной мощностью

# %%
# Добавляем столбец с продолжительностью нагрева
data_arc['heating_duration'] = (data_arc['end_heating_arc'] - data_arc['start_heating_arc']).dt.total_seconds() / 60 # В минутах

# Проверяем на отрицательные значения
negative_duration_rows = data_arc[data_arc['heating_duration'] < 0]
negative_duration_keys = negative_duration_rows['key'].unique()

# Выводим количество строк и ключей с отрицательными значениями
print(f"Количество строк с отрицательной продолжительностью нагрева: {len(negative_duration_rows)}")
print(f"Количество ключей с отрицательной продолжительностью нагрева: {len(negative_duration_keys)}")
# Out:
# Количество строк с отрицательной продолжительностью нагрева: 0
# Количество ключей с отрицательной продолжительностью нагрева: 0

# %% [markdown]
# Активная мощность и реактивная мощность имеют схожее распределение с относительно низкими значениями и умеренной вариативностью.
# Большинство значений мощности сосредоточены в узком диапазоне, что может говорить о контролируемом технологическом процессе.
# Также проверили логичность данных, чтоб начальная температура не превышала конечную.

# %%
# Агрегация данных по ключу (key)
aggregated_data_arc = data_arc.groupby('key').agg({
    'start_heating_arc': ['min'],
    'end_heating_arc': ['max'],
    'active_power': ['count', 'mean', 'sum'],
    'reactive_power': ['mean', 'sum']
}).reset_index()

# Упрощение мультииндекса в столбцах
aggregated_data_arc.columns = [
    'key', 
    'start_heating_arc', 'end_heating_arc',
    'iteration_count', 
    'active_power_mean', 'active_power_sum',
    'reactive_power_mean', 'reactive_power_sum'
]

# Добавляем полную мощность в агрегированный датафрейм
aggregated_data_arc['total_power_mean'] = (
    aggregated_data_arc['active_power_mean']**2 + aggregated_data_arc['reactive_power_mean']**2
)**0.5

aggregated_data_arc['total_power_sum'] = (
    aggregated_data_arc['active_power_sum']**2 + aggregated_data_arc['reactive_power_sum']**2
)**0.5

# Добавляем время нагрева дугой (разница между последним окончанием и первым началом)
aggregated_data_arc['heating_duration'] = (
    aggregated_data_arc['end_heating_arc'] - aggregated_data_arc['start_heating_arc']
).dt.total_seconds() / 60  # В минутах

# %%
# Вывод результата
display(aggregated_data_arc.head())
display(aggregated_data_arc.describe())
aggregated_data_arc.info()
# Out:
#    key   start_heating_arc     end_heating_arc  iteration_count  \
# 0    1 2019-05-03 11:02:14 2019-05-03 11:28:37                5
# 1    2 2019-05-03 11:34:14 2019-05-03 11:53:18                4
# 2    3 2019-05-03 12:06:54 2019-05-03 12:32:19                5
# 3    4 2019-05-03 12:39:37 2019-05-03 12:57:50                4
# 4    5 2019-05-03 13:11:13 2019-05-03 13:33:55                4
#
#    active_power_mean  active_power_sum  reactive_power_mean  \
# 0           0.607346          3.036730             0.428564
# 1           0.534852          2.139408             0.363339
# 2           0.812728          4.063641             0.587491
# 3           0.676622          2.706489             0.514248
# 4           0.563238          2.252950             0.421998
#
#    reactive_power_sum  total_power_mean  total_power_sum  heating_duration
# 0            2.142821          0.743328         3.716640         26.383333
# ...

# %%
plot_numerical_distribution(aggregated_data_arc, ['iteration_count',
                                                  'active_power_mean','active_power_sum',
                                                  'reactive_power_mean', 'reactive_power_sum',
                                                  'total_power_mean', 'total_power_sum'])

# %%
# Проверяем на отрицательные значения
negative_duration_rows = aggregated_data_arc[aggregated_data_arc['heating_duration'] < 0]

# Выводим количество строк и ключей с отрицательными значениями
print(f"Количество строк с отрицательной продолжительностью нагрева: {len(negative_duration_rows)}")
# Out:
# Количество строк с отрицательной продолжительностью нагрева: 0

# %% [markdown]
# Логика технологисеского процесса предполагает, что нагрев электродами должен происходить в промежутке между первым и последним замером температуры. Если время нагрева выходит за эти границы, это может указывать на ошибку в данных или некорректную запись. Проверим, есть ли такие данные в таблице.

# %%
# Добавляем в data_bulk_time столбцы first_temp_measurement и last_temp_measurement из temp_summary
aggregated_data_arc_temp = pd.merge(
    aggregated_data_arc,
    temp_summary[['key', 'first_temp_measurement', 'last_temp_measurement']],
    on='key',
    how='left'
)

# %%
# Определяем столбцы с временем добавления сыпучих материалов
arc_time_columns = ['start_heating_arc', 'end_heating_arc']

# Применяем функцию к каждой строке
aggregated_data_arc_temp['invalid_timing'] = aggregated_data_arc_temp.apply(
    lambda row: check_timing(row, arc_time_columns, 'first_temp_measurement', 'last_temp_measurement'),
    axis=1
)

# Выводим количество строк с invalid_timing = True
invalid_timing_count = aggregated_data_arc_temp['invalid_timing'].sum()
print(f"Количество строк с недопустимым временем добавления сыпучих материалов: {invalid_timing_count}")
display(aggregated_data_arc_temp[aggregated_data_arc_temp['invalid_timing'] == True])
# Out:
# Количество строк с недопустимым временем добавления сыпучих материалов: 4
#        key   start_heating_arc     end_heating_arc  iteration_count  \
# 853    867 2019-06-06 08:03:49 2019-06-06 08:44:19                7
# 1199  1214 2019-06-18 08:01:13 2019-06-18 08:32:22                3
# 1602  1619 2019-07-03 02:34:51 2019-07-03 02:41:28                2
# 2034  2052 2019-07-25 08:49:25 2019-07-25 09:21:38                5
#
#       active_power_mean  active_power_sum  reactive_power_mean  \
# 853            0.692203          4.845421             0.514895
# 1199           0.658810          1.976430             0.521283
# 1602           0.482439          0.964878             0.391147
# 2034           0.580014          2.900068             0.455515
#
#       reactive_power_sum  total_power_mean  total_power_sum  heating_duration  \
# 853             3.604263          0.862706         6.038942         40.500000
# ...

# %%
keys_to_remove = set()

# Добавляем ключи с недопустимыми добавлениями в список keys_to_remove
invalid_keys = aggregated_data_arc_temp[aggregated_data_arc_temp['invalid_timing']]['key'].unique()
keys_to_remove.update(invalid_keys)
print(keys_to_remove)
# Out:
# {1619, 867, 2052, 1214}

# %% [markdown]
# 1. Количество итераций нагрева: Большинство партий проходят от 4 до 6 итераций нагрева. Партии с большим количеством итераций (например, 16) могут быть аномалиями или требовать дополнительного анализа. Возможно, партии с большим количеством итераций требуют больше энергии для достижения целевой температуры.
# 2. Мощность: Активная и реактивная мощности стабильны, но есть выбросы (например, максимальные значения).
# 3. Полная мощность: Полная мощность коррелирует с активной и реактивной мощностью, но её значения выше, так как она учитывает оба типа мощности.

# %% [markdown]
# #### data_bulk — данные о подаче сыпучих материалов (объём)

# %%
display(data_bulk.head())
data_bulk.info()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ...

# %%
data_bulk.columns = [col.replace(' ', '_').replace('Bulk', 'bulk') for col in data_bulk.columns]

# %%
# Статистика по каждому материалу
bulk_stats = data_bulk.describe().transpose()
print("Статистика по добавленным материалам:")
display(bulk_stats)
# Out:
# Статистика по добавленным материалам:
#           count         mean         std    min     25%     50%      75%  \
# key      3129.0  1624.383509  933.337642    1.0  816.00  1622.0  2431.00
# bulk_1    252.0    39.242063   18.277654   10.0   27.00    31.0    46.00
# bulk_2     22.0   253.045455   21.180578  228.0  242.00   251.5   257.75
# bulk_3   1298.0   113.879045   75.483494    6.0   58.00    97.5   152.00
# bulk_4   1014.0   104.394477   48.184126   12.0   72.00   102.0   133.00
# bulk_5     77.0   107.025974   81.790646   11.0   70.00    86.0   132.00
# bulk_6    576.0   118.925347   72.057776   17.0   69.75   100.0   157.00
# bulk_7     25.0   305.600000  191.022904   47.0  155.00   298.0   406.00
# bulk_8      1.0    49.000000         NaN   49.0   49.00    49.0    49.00
# bulk_9     19.0    76.315789   21.720581   63.0   66.00    68.0    70.50
# bulk_10   176.0    83.284091   26.060347   24.0   64.00    86.5   102.00
# ...

# %% [markdown]
# Так как пропуски в столбцах, вероятно, означают отсутствие добавленного материала, их логично заменить на нули. Это также приведёт данные к удобному виду для анализа.

# %%
# Заполнение пропусков нулями
data_bulk.fillna(0, inplace=True)

# %%
# Количество ненулевых значений
non_zero_counts = data_bulk.iloc[:, 1:].astype(bool).sum()
print("Количество ненулевых значений для каждого материала:")
print(non_zero_counts)
# Out:
# Количество ненулевых значений для каждого материала:
# bulk_1      252
# bulk_2       22
# bulk_3     1298
# bulk_4     1014
# bulk_5       77
# bulk_6      576
# bulk_7       25
# bulk_8        1
# bulk_9       19
# bulk_10     176
# bulk_11     177
# bulk_12    2450
# bulk_13      18
# bulk_14    2806
# bulk_15    2248
# dtype: int64

# %% [markdown]
# Описание данных:
# - Всего 3129 записей (наблюдений).
# - Присутствуют 15 столбцов, обозначающих количество добавленных материалов (`Bulk 1` - `Bulk 15`), и идентификатор (`key`).
# - Значения в столбцах материалов сильно варьируются от минимального (0) до максимального (до нескольких сотен или даже тысяч).
#
# Часто используемые материалы:
# - `Bulk 12` (2450 ненулевых значений) — основной материал, вероятно используемый почти в каждой плавке.
# - `Bulk 14` (2806 ненулевых значений) — ещё один часто добавляемый материал.
# - `Bulk 15` (2248 ненулевых значений) — также часто используется.
#
# Редко используемые материалы:
# - `Bulk 8` (1 ненулевое значение) — практически отсутствует, возможно, ошибка в данных или материал был использован в экспериментальной плавке.
# - `Bulk 13` (18 ненулевых значений) — добавляется очень редко.
# - `Bulk 9` и `Bulk 7` (19 и 25 ненулевых значений соответственно) также являются редкими.
#
# Среднее количество (mean):
# - Большинство материалов имеют низкие средние значения, что указывает на их редкое использование или небольшие дозировки.
# - Наибольшее среднее значение у `Bulk 12` (203.95), `Bulk 14` (152.71) и `Bulk 15` (115.32), что подтверждает их значительную роль в процессе.
#
# Вариация данных (std):
# - Высокие стандартные отклонения у `Bulk 12`, `Bulk 14`, и `Bulk 15` (151.42, 81.09 и 84.49 соответственно) говорят о значительной изменчивости их количества в разных плавках.
# - У редких материалов (`Bulk 8`, `Bulk 9`, `Bulk 13`) стандартные отклонения также низкие, что логично, так как их использования практически нет.
#
# Максимальные значения (max):
# - `Bulk 12` имеет максимальное значение 1849, что значительно превышает другие материалы. Это может быть связано с крупной партией производства.
# - `Bulk 7` и `Bulk 9` имеют необычно высокие максимумы (772 и 147 соответственно) по сравнению с их средними значениями, что может быть аномалией.
# - Остальные значения выглядят в пределах разумного.
#
# Медианы и квартили:
# - У большинства материалов медианы равны 0, что подтверждает их редкое использование.
# - Для часто используемых (`Bulk 12`, `Bulk 14`, `Bulk 15`):
#      - Медиана близка к среднему, что говорит о симметричности распределения.
#      - Верхние квартильные значения подтверждают их значимость.
#
# **Вывод:**
# 1. Ключевые материалы:
#    - `Bulk 12`, `Bulk 14`, и `Bulk 15` являются основными материалами, без которых, похоже, не обходится большинство плавок.
# 2. Редкие материалы:
#    - `Bulk 8` практически отсутствует.
#    - `Bulk 13`, `Bulk 9`, и `Bulk 7` также редко используются. Нужно проверить их влияние на результаты, чтобы понять их значимость.
# 3. Аномалии:
#    - Очень высокие максимумы у некоторых материалов (`Bulk 7`, `Bulk 9`, `Bulk 12`) стоит перепроверить — это могут быть выбросы или особенности технологического процесса.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошо, что есть промежуточный вывод)

# %% [markdown]
# #### data_bulk_time — данные о подаче сыпучих материалов (время)

# %%
display(data_bulk_time.head())
data_bulk_time.info()
# Out:
#    key Bulk 1 Bulk 2 Bulk 3              Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaT    NaT    NaT 2019-05-03 11:28:48    NaT    NaT    NaT    NaT
# 1    2    NaT    NaT    NaT 2019-05-03 11:36:50    NaT    NaT    NaT    NaT
# 2    3    NaT    NaT    NaT 2019-05-03 12:32:39    NaT    NaT    NaT    NaT
# 3    4    NaT    NaT    NaT 2019-05-03 12:43:22    NaT    NaT    NaT    NaT
# 4    5    NaT    NaT    NaT 2019-05-03 13:30:47    NaT    NaT    NaT    NaT
#
#   Bulk 9 Bulk 10 Bulk 11             Bulk 12 Bulk 13             Bulk 14  \
# 0    NaT     NaT     NaT 2019-05-03 11:24:31     NaT 2019-05-03 11:14:50
# 1    NaT     NaT     NaT 2019-05-03 11:53:30     NaT 2019-05-03 11:48:37
# 2    NaT     NaT     NaT 2019-05-03 12:27:13     NaT 2019-05-03 12:21:01
# 3    NaT     NaT     NaT 2019-05-03 12:58:00     NaT 2019-05-03 12:51:11
# 4    NaT     NaT     NaT 2019-05-03 13:30:47     NaT 2019-05-03 13:34:12
#
#               Bulk 15
# 0 2019-05-03 11:10:43
# 1 2019-05-03 11:44:39
# ...

# %%
data_bulk.columns = [col.replace(' ', '_').replace('Bulk', 'bulk') for col in data_bulk.columns]

# %%
# Инициализация пустого DataFrame для хранения статистики
bulk_datetime_stats = pd.DataFrame(columns=['Count', 'Min', 'Max', 'Range', 'Mean', 'Median'])

# Цикл по всем столбцам в data_bulk_time_datetime
for column in data_bulk_time.columns:
    if pd.api.types.is_datetime64_any_dtype(data_bulk_time[column]):
        bulk_datetime_stats.loc[column, 'Count'] = data_bulk_time[column].count()
        bulk_datetime_stats.loc[column, 'Min'] = data_bulk_time[column].min()
        bulk_datetime_stats.loc[column, 'Max'] = data_bulk_time[column].max()
        bulk_datetime_stats.loc[column, 'Range'] = data_bulk_time[column].max() - data_bulk_time[column].min()
        bulk_datetime_stats.loc[column, 'Mean'] = data_bulk_time[column].mean()
        bulk_datetime_stats.loc[column, 'Median'] = data_bulk_time[column].median()
        
print("Статистика по признакам datetime:")
display(bulk_datetime_stats)
# Out:
# Статистика по признакам datetime:
#         Count                  Min                  Max              Range  \
# Bulk 1    252  2019-05-03 17:42:46  2019-09-05 09:11:32  124 days 15:28:46
# Bulk 2     22  2019-05-07 15:39:35  2019-08-13 11:47:39   97 days 20:08:04
# Bulk 3   1298  2019-05-03 20:40:25  2019-09-06 12:26:52  125 days 15:46:27
# Bulk 4   1014  2019-05-03 11:28:48  2019-09-05 03:35:21  124 days 16:06:33
# Bulk 5     77  2019-05-07 15:19:17  2019-09-02 18:16:52  118 days 02:57:35
# Bulk 6    576  2019-05-03 19:09:15  2019-09-06 16:24:28  125 days 21:15:13
# Bulk 7     25  2019-05-07 18:11:01  2019-09-05 19:07:49  121 days 00:56:48
# Bulk 8      1  2019-07-08 17:14:53  2019-07-08 17:14:53    0 days 00:00:00
# Bulk 9     19  2019-05-14 11:57:58  2019-08-16 09:11:56   93 days 21:13:58
# Bulk 10   176  2019-05-06 07:54:02  2019-09-04 10:03:22  121 days 02:09:20
# Bulk 11   177  2019-05-05 23:43:24  2019-09-06 05:03:14  123 days 05:19:50
# ...

# %% [markdown]
# По технологии перед плавлением темпрература и состав сплава измеряется и далее добавляются добавки, потом температура и состав измеряются снова. Цикл повторяется, пока состав не будет нужным. Это означает, что сыпучие не могут добавлятся в сплав до первого замера и после последнего замера. Поэтому проверим на наличие времени добавления сыпучих в сплав до первого и после последнего замеров.

# %%
# Добавляем в data_bulk_time столбцы first_temp_measurement и last_temp_measurement из temp_summary
data_bulk_time_with_temp = pd.merge(
    data_bulk_time,
    temp_summary[['key', 'first_temp_measurement', 'last_temp_measurement']],
    on='key',
    how='left'
)

# %%
# Определяем столбцы с временем добавления сыпучих материалов
bulk_time_columns = data_bulk_time.columns[1:]  # Пропускаем первый столбец (key)

# Применяем функцию к каждой строке
data_bulk_time_with_temp['invalid_timing'] = data_bulk_time_with_temp.apply(
    lambda row: check_timing(row, bulk_time_columns, 'first_temp_measurement', 'last_temp_measurement'),
    axis=1
)

# Выводим количество строк с invalid_timing = True
invalid_timing_count = data_bulk_time_with_temp['invalid_timing'].sum()
print(f"Количество строк с недопустимым временем добавления сыпучих материалов: {invalid_timing_count}")
display(data_bulk_time_with_temp[data_bulk_time_with_temp['invalid_timing'] == True])
# Out:
# Количество строк с недопустимым временем добавления сыпучих материалов: 1
#        key Bulk 1 Bulk 2              Bulk 3 Bulk 4 Bulk 5 Bulk 6 Bulk 7  \
# 1561  1619    NaT    NaT 2019-07-03 02:37:20    NaT    NaT    NaT    NaT
#
#      Bulk 8 Bulk 9 Bulk 10 Bulk 11 Bulk 12 Bulk 13 Bulk 14 Bulk 15  \
# 1561    NaT    NaT     NaT     NaT     NaT     NaT     NaT     NaT
#
#      first_temp_measurement last_temp_measurement  invalid_timing
# 1561    2019-07-03 02:39:29   2019-07-03 02:43:59            True

# %%
# Добавляем ключи с недопустимыми добавлениями в список keys_to_remove
invalid_keys = data_bulk_time_with_temp[data_bulk_time_with_temp['invalid_timing']]['key'].unique()
keys_to_remove.update(invalid_keys)
print(keys_to_remove)
# Out:
# {1619, 867, 2052, 1214}

# %% [markdown]
# #### data_gas — данные о продувке сплава газом

# %%
# Переименование столбцов 
rename_dict = {
    'Газ 1': 'gas'
} 

data_gas.rename(columns=rename_dict, inplace=True)

# %%
display(data_gas.head())
data_gas.info()
# Out:
#    key        gas
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   gas     3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
# Анализ распределения признаков
plot_numerical_distribution(data_gas, ['gas'])

# %%
# Удаляем выбросы - выше 50
data_gas_cleaned = data_gas[data_gas['gas'] < 50].copy()

# Проверка распределения после удаления выбросов
plot_numerical_distribution(data_gas_cleaned, ['gas'])
display(data_gas_cleaned.describe())
data_gas_cleaned.info()
# Out:
#                key          gas
# count  3234.000000  3234.000000
# mean   1622.699443    10.928461
# std     934.969652     5.922425
# min       1.000000     0.008399
# 25%     814.250000     7.038335
# 50%    1622.500000     9.825443
# 75%    2431.750000    13.754024
# max    3241.000000    45.638999
# <class 'pandas.core.frame.DataFrame'>
# Index: 3234 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3234 non-null   int64
#  1   gas     3234 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 75.8 KB

# %%
# Добавляем ключи выбросов в переменную keys_to_remove
invalid_gas_keys = data_gas[data_gas['gas'] >= 50]['key'].unique()
keys_to_remove.update(invalid_gas_keys)
print(keys_to_remove)
# Out:
# {322, 867, 2052, 2570, 1619, 117, 280, 2110, 1214}

# %% [markdown]
# Распределение смещено вправо (есть длинный "хвост"), что подтверждается редкими высокими значениями, видными на графике.
# Большая часть данных сосредоточена в диапазоне от 0 до 20 единиц.

# %% [markdown]
# #### data_wire — данные о проволочных материалах (объём)

# %%
display(data_wire.head())
data_wire.info()
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
# ...

# %%
data_wire.columns = [col.replace(' ', '_').replace('Wire', 'wire') for col in data_wire.columns]

# %%
# Статистика по каждому материалу
wire_stats = data_wire.describe().transpose()
print("Статистика по добавленным материалам:")
display(wire_stats)
# Out:
# Статистика по добавленным материалам:
#          count         mean         std        min         25%          50%  \
# key     3081.0  1623.426485  932.996726   1.000000  823.000000  1619.000000
# wire_1  3055.0   100.895853   42.012518   1.918800   72.115684   100.158234
# wire_2  1079.0    50.577323   39.320216   0.030160   20.193680    40.142956
# wire_3    63.0   189.482681   99.513444   0.144144   95.135044   235.194977
# wire_4    14.0    57.442841   28.824667  24.148801   40.807002    45.234282
# wire_5     1.0    15.132000         NaN  15.132000   15.132000    15.132000
# wire_6    73.0    48.016974   33.919845   0.034320   25.053600    42.076324
# wire_7    11.0    10.039007    8.610584   0.234208    6.762756     9.017009
# wire_8    19.0    53.625193   16.881728  45.076721   46.094879    46.279999
# wire_9    29.0    34.155752   19.931616   4.622800   22.058401    30.066399
#
#                 75%          max
# key     2434.000000  3241.000000
# ...

# %%
# Заполнение пропусков нулями
data_wire.fillna(0, inplace=True)

# %%
# Количество ненулевых значений
non_zero_counts = data_wire.iloc[:, 1:].astype(bool).sum()
print("Количество ненулевых значений для каждого материала:")
print(non_zero_counts)
# Out:
# Количество ненулевых значений для каждого материала:
# wire_1    3055
# wire_2    1079
# wire_3      63
# wire_4      14
# wire_5       1
# wire_6      73
# wire_7      11
# wire_8      19
# wire_9      29
# dtype: int64

# %% [markdown]
# - `Wire 1` является наиболее значимым материалом, так как он представлен практически в каждой партии (3055 из 3081). Его объемы широко варьируются, что указывает на его ключевую роль в процессе.
# - `Wire 5` (1 значение), `Wire 4` (14 значений), `Wire 7` (11 значений), и `Wire 8` (19 значений) содержат слишком мало данных для анализа и, вероятно, не имеют значимого вклада в процесс. Их можно исключить из дальнейшего анализа.
# - Несколько материалов, таких как `Wire 3`, имеют сильные выбросы (объемы превышают 300). Это может быть результатом нестандартных партий или ошибок измерений.

# %% [markdown]
# #### data_wire_time — данные о проволочных материалах (время)

# %%
display(data_wire_time.head())
data_wire_time.info()
# Out:
#    key              Wire 1              Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1 2019-05-03 11:06:19                 NaT    NaT    NaT    NaT    NaT
# 1    2 2019-05-03 11:36:50                 NaT    NaT    NaT    NaT    NaT
# 2    3 2019-05-03 12:11:46                 NaT    NaT    NaT    NaT    NaT
# 3    4 2019-05-03 12:43:22                 NaT    NaT    NaT    NaT    NaT
# 4    5 2019-05-03 13:20:44 2019-05-03 13:15:34    NaT    NaT    NaT    NaT
#
#   Wire 7 Wire 8 Wire 9
# 0    NaT    NaT    NaT
# 1    NaT    NaT    NaT
# 2    NaT    NaT    NaT
# 3    NaT    NaT    NaT
# 4    NaT    NaT    NaT
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   datetime64[ns]
#  2   Wire 2  1079 non-null   datetime64[ns]
#  3   Wire 3  63 non-null     datetime64[ns]
# ...

# %%
# Инициализация пустого DataFrame для хранения статистики
wire_datetime_stats = pd.DataFrame(columns=['Count', 'Min', 'Max', 'Range', 'Mean', 'Median'])

# Цикл по всем столбцам в data_bulk_time_datetime
for column in data_wire_time.columns:
    if pd.api.types.is_datetime64_any_dtype(data_wire_time[column]):
        wire_datetime_stats.loc[column, 'Count'] = data_wire_time[column].count()
        wire_datetime_stats.loc[column, 'Min'] = data_wire_time[column].min()
        wire_datetime_stats.loc[column, 'Max'] = data_wire_time[column].max()
        wire_datetime_stats.loc[column, 'Range'] = data_wire_time[column].max() - data_wire_time[column].min()
        wire_datetime_stats.loc[column, 'Mean'] = data_wire_time[column].mean()
        wire_datetime_stats.loc[column, 'Median'] = data_wire_time[column].median()
        
print("Статистика по признакам datetime:")
display(wire_datetime_stats)
# Out:
# Статистика по признакам datetime:
#        Count                  Min                  Max              Range  \
# Wire 1  3055  2019-05-03 11:06:19  2019-09-06 17:10:06  126 days 06:03:47
# Wire 2  1079  2019-05-03 13:15:34  2019-09-06 07:35:40  125 days 18:20:06
# Wire 3    63  2019-05-04 04:34:27  2019-09-02 07:14:44  121 days 02:40:17
# Wire 4    14  2019-05-07 15:19:17  2019-08-13 03:16:45   97 days 11:57:28
# Wire 5     1  2019-08-13 06:14:30  2019-08-13 06:14:30    0 days 00:00:00
# Wire 6    73  2019-05-07 14:46:05  2019-08-18 19:10:56  103 days 04:24:51
# Wire 7    11  2019-07-27 05:49:05  2019-08-13 10:25:22   17 days 04:36:17
# Wire 8    19  2019-05-14 11:29:24  2019-08-16 08:56:23   93 days 21:26:59
# Wire 9    29  2019-05-04 17:21:27  2019-09-03 12:55:23  121 days 19:33:56
#
#                                  Mean                      Median
# Wire 1  2019-07-05 23:22:34.279541760         2019-07-03 06:36:23
# ...

# %% [markdown]
# Аналогично `data_bulk_time`, проверим наличие нелогичных данных с временем добавления проволочных материалах до первого и после последнего замеров.

# %%
# Добавляем в data_wire_time столбцы first_temp_measurement и last_temp_measurement из temp_summary
data_wire_time_with_temp = pd.merge(
    data_wire_time,
    temp_summary[['key', 'first_temp_measurement', 'last_temp_measurement']],
    on='key',
    how='left'
)

# %%
# Определяем столбцы с временем добавления сыпучих материалов
wire_time_columns = data_wire_time.columns[1:]  # Пропускаем первый столбец (key)

# Применяем функцию к каждой строке
data_wire_time_with_temp['invalid_timing'] = data_wire_time_with_temp.apply(
    lambda row: check_timing(row, wire_time_columns, 'first_temp_measurement', 'last_temp_measurement'),
    axis=1
)

# Выводим количество строк с invalid_timing = True
invalid_timing_count = data_wire_time_with_temp['invalid_timing'].sum()
print(f"Количество строк с недопустимым временем добавления проволочных материалов: {invalid_timing_count}")
display(data_wire_time_with_temp[data_wire_time_with_temp['invalid_timing'] == True])
# Out:
# Количество строк с недопустимым временем добавления проволочных материалов: 3
#        key              Wire 1              Wire 2 Wire 3 Wire 4 Wire 5  \
# 1146  1214 2019-06-18 08:02:57                 NaT    NaT    NaT    NaT
# 1540  1619 2019-07-03 02:41:39 2019-07-03 02:37:20    NaT    NaT    NaT
# 1955  2052 2019-07-25 08:51:13                 NaT    NaT    NaT    NaT
#
#      Wire 6 Wire 7 Wire 8 Wire 9 first_temp_measurement last_temp_measurement  \
# 1146    NaT    NaT    NaT    NaT    2019-06-18 08:17:56   2019-06-18 08:43:56
# 1540    NaT    NaT    NaT    NaT    2019-07-03 02:39:29   2019-07-03 02:43:59
# 1955    NaT    NaT    NaT    NaT    2019-07-25 08:54:39   2019-07-25 09:27:03
#
#       invalid_timing
# 1146            True
# 1540            True
# 1955            True

# %%
# Добавляем ключи с недопустимыми добавлениями в список keys_to_remove
invalid_keys = data_wire_time_with_temp[data_wire_time_with_temp['invalid_timing']]['key'].unique()
keys_to_remove.update(invalid_keys)
print(keys_to_remove)
# Out:
# {322, 867, 2052, 2570, 1619, 117, 280, 2110, 1214}

# %% [markdown]
# Были исследованы все признаки и данные подготовлены для дальнейшего анализа:
# - Выявлены аномальные значения температуры, мощности и объема газа, которые были удалены.
# - Некоторые материалы (например, Bulk 8, Wire 5) используются крайне редко и, возможно, не имеют значимого влияния на процесс.
# - Проверено соответствие времени добавления материалов и нагрева временным границам замеров температуры. Выявлены недопустимые добавления, которые были исключены из анализа.
# - Конечная температура и мощность находятся под строгим контролем, что указывает на стандартизированный технологический процесс.

# %% [markdown]
# ### Объединение данных

# %%
temp_summary.info()
print()
print('----------------------')
aggregated_data_arc.info()
print()
print('----------------------')
data_bulk.info()
print()
print('----------------------')
data_gas.info()
print()
print('----------------------')
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2475 entries, 0 to 2474
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   key                        2475 non-null   int64
#  1   temp_start                 2475 non-null   float64
#  2   temp_end                   2475 non-null   float64
#  3   first_temp_measurement     2475 non-null   datetime64[ns]
#  4   last_temp_measurement      2475 non-null   datetime64[ns]
#  5   temp_measurement_duration  2475 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(1)
# memory usage: 116.1 KB
#
# ----------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3213 entries, 0 to 3212
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   key                  3213 non-null   int64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Мне интересно было изучить проведенный исследовательский анализ данных, твои графики, осмысленный и красочный графический анализ. Найдены очень интересные закономерности)
#
# <div class="alert alert-block alert-danger">
#
#
#
# <b>На доработку🤔:</b>
#
#
# Нужно еще написать вывод по результатам проведенного исследовательского анализа данных до объединения

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Добавил в самом конце исследовательского анализа
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# Объединение таблиц
merged_data = (
    temp_summary
    .merge(aggregated_data_arc, on="key", how="inner")
    .merge(data_bulk, on="key", how="inner")
    .merge(data_gas, on="key", how="inner")
    .merge(data_wire, on="key", how="inner")
)

# Установка столбца 'key' в качестве индекса
merged_data.set_index('key', inplace=True)

# %%
merged_data = merged_data.drop(['first_temp_measurement', 'last_temp_measurement'], axis=True)

# %%
# Информация о финальном датафрейме
print("Информация о объединённом датафрейме:")
merged_data.info()
print()
print('-------------------------------------')
print('Дубкликаты: ', merged_data.duplicated().sum())
print()
print('-------------------------------------')
display(merged_data.head())
display(merged_data.tail())
# Out:
# Информация о объединённом датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2328 entries, 1 to 2499
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   temp_start                 2328 non-null   float64
#  1   temp_end                   2328 non-null   float64
#  2   temp_measurement_duration  2328 non-null   float64
#  3   start_heating_arc          2328 non-null   datetime64[ns]
#  4   end_heating_arc            2328 non-null   datetime64[ns]
#  5   iteration_count            2328 non-null   int64
#  6   active_power_mean          2328 non-null   float64
#  7   active_power_sum           2328 non-null   float64
#  8   reactive_power_mean        2328 non-null   float64
#  9   reactive_power_sum         2328 non-null   float64
#  10  total_power_mean           2328 non-null   float64
#  11  total_power_sum            2328 non-null   float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, партии, для которых не все замеры температуры известны удалены, таблицы объединены верно

# %% [markdown]
# ### Исследовательский анализ и предобработка данных объединённого датафрейма

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера     <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# После объединения таблиц, для итогового датафрейма нужно вывести графики распределения (или боксплоты) ВСЕХ признаков

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Добавил распределение всех прихнаков ниже.
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
# Добавляем новые признаки
merged_data['active_reactive_power_interaction'] = merged_data['active_power_sum'] * merged_data['gas']
merged_data['heating_duration_per_iteration'] = merged_data['heating_duration'] / merged_data['iteration_count']

# %%
from matplotlib.gridspec import GridSpec

# Список числовых столбцов (исключаем datetime и key)
numerical_columns = [col for col in merged_data.columns if merged_data[col].dtype in ['float64', 'int64']]

# Определяем количество строк для субплотов
num_plots = len(numerical_columns)
num_rows = (num_plots + 1) // 2  # Округляем вверх

# Создаем фигуру с субплотами
fig = plt.figure(figsize=(16, num_rows * 6))
gs = GridSpec(num_rows * 2, 2, height_ratios=[3, 1] * num_rows)  # 3:1 для гистограммы и боксплота

# Проходим по каждому столбцу и строим распределение
for i, col in enumerate(numerical_columns):
    row = (i // 2) * 2  # Умножаем на 2, так как каждая пара гистограмма+боксплот занимает 2 строки
    col_idx = i % 2
    
    # Гистограмма
    ax_hist = fig.add_subplot(gs[row, col_idx])
    sns.histplot(merged_data[col].dropna(), bins=30, kde=False, ax=ax_hist, color='blue', edgecolor='black')
    ax_hist.set_title(f'Распределение {col}', fontsize=12, fontweight='bold')
    ax_hist.set_xlabel(None)
    ax_hist.set_ylabel('Частота', fontsize=10)
    ax_hist.grid(axis='y', linestyle='--', alpha=0.5)
    
    # Боксплот
    ax_box = fig.add_subplot(gs[row + 1, col_idx])
    sns.boxplot(x=merged_data[col].dropna(), ax=ax_box, color='blue')
    ax_box.set_xlabel(col, fontsize=10)
    ax_box.set_ylabel(None)

# Убираем пустые субплоты, если количество признаков нечетное
if num_plots % 2 != 0:
    fig.delaxes(fig.add_subplot(gs[-1, -1]))

plt.tight_layout()
plt.show()

# %%
# Вычисление корреляционной матрицы
correlation_matrix = merged_data.corr()

# %%
# Установка размера графика
plt.figure(figsize=(16, 20))

# Построение тепловой карты
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    fmt=".2f", 
    cmap='coolwarm', 
    cbar_kws={"orientation": "horizontal", "shrink": 0.8, "aspect": 40},
    annot_kws={"size": 8}  # Уменьшение размера шрифта аннотаций
)

# Настройка заголовка
plt.title("Correlation Matrix", fontsize=16)

# Настройка размера шрифта меток осей
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Отображение графика
plt.show()

# %% [markdown]
# Корреляция с целевой переменной (temp_end):
# - temp_start: Умеренная положительная корреляция (0.30). Начальная температура влияет на конечную.
# - bulk_12, bulk_14, bulk_15: Умеренная положительная корреляция (0.27, 0.11, 0.27). Эти материалы часто используются в процессе.
# - wire_1: Умеренная положительная корреляция (0.32). Проволочный материал активно используется.
# - gas: Слабая положительная корреляция (0.06). Продувка газом важна для процесса, но слабо влияет на температуру.
#
# Мультиколлинеарность:
# - active_power_mean и reactive_power_mean: Высокая корреляция (0.97). Оставим только active_power_mean.
# - active_power_sum и reactive_power_sum: Высокая корреляция (0.99). Оставим только active_power_sum.
# - total_power_mean и total_power_sum: Почти полностью коррелируют с active_power_mean и active_power_sum (корреляция > 0.99). Исключаем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проверяешь попарные корреляции признаков

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Для прогноза температуры (temp_end) были выбраны следующие признаки:
#
# - Температурные признаки:
#     - temp_start: Начальная температура имеет умеренную корреляцию с целевой переменной (0.30) и является важным фактором.
#     - temp_measurement_duration: Время измерения температуры включено, так как оно отражает продолжительность процесса.
#     - heating_duration: Длительность нагрева включена, так как она влияет на конечную температуру.
#
# - Признаки, связанные с мощностью:
#     - active_power_sum: Суммарная активная мощность имеет умеренную корреляцию с целевой переменной (0.18) и важна для процесса нагрева.
#
# - Признаки, связанные с материалами:
#     - bulk_12, bulk_14, bulk_15: Эти материалы часто используются в процессе и имеют умеренную корреляцию с целевой переменной.
#     - wire_1, wire_2: Проволочные материалы активно используются и влияют на процесс.
#
# - Признаки, связанные с газом:
#     - gas: Продувка газом является важным этапом технологического процесса, хотя и имеет слабую корреляцию с целевой переменной.
#
# - Новые признаки:
#     - active_reactive_power_interaction: Взаимодействие активной и реактивной мощности.
#     - heating_duration_per_iteration: Отношение времени нагрева к количеству итераций.
#
# Эти признаки обеспечивают баланс между информативностью и простотой модели, минимизируя риск переобучения.

# %%
# Создаем новый датафрейм с выбранными признаками
selected_features = [
    'temp_measurement_duration', 'iteration_count', 
    'active_power_sum', 'heating_duration', 'temp_start',
    'bulk_12', 'bulk_14', 'bulk_15',
    'wire_1', 'wire_2', 'gas', 'temp_end',
    'active_reactive_power_interaction', 'heating_duration_per_iteration'
]

data = merged_data[selected_features]

display(data.head())
data.info()
# Out:
#      temp_measurement_duration  iteration_count  active_power_sum  \
# key
# 1                    28.566667                5          3.036730
# 2                    21.083333                4          2.139408
# 3                    29.216667                5          4.063641
# 4                    20.333333                4          2.706489
# 5                    25.600000                4          2.252950
#
#      heating_duration  temp_start  bulk_12  bulk_14  bulk_15     wire_1  \
# key
# 1           26.383333      1571.0    206.0    150.0    154.0  60.059998
# 2           19.066667      1581.0    206.0    149.0    154.0  96.052315
# 3           25.416667      1596.0    205.0    152.0    153.0  91.160157
# 4           18.216667      1601.0    207.0    153.0    154.0  89.063515
# 5           22.700000      1576.0    203.0    151.0    152.0  89.238236
#
#       wire_2        gas  temp_end  active_reactive_power_interaction  \
# key
# ...

# %%
# Разделяем с учетом целевой переменной temp_end
train_data, test_data = train_test_split(data, test_size=0.25, random_state=RANDOM_STATE)

# %%
# Удаляем аномальные данные с помошью подготовленного списка ключей
train_data = train_data[~train_data.index.isin(keys_to_remove)]

# Выводим размеры итоговых датафреймов
print(f"Размер тренировочной выборки: {train_data.shape}")
print(f"Размер тестовой выборки: {test_data.shape}")
# Out:
# Размер тренировочной выборки: (1738, 14)
# Размер тестовой выборки: (582, 14)

# %%
X_train = train_data.drop('temp_end', axis=True)
y_train = train_data['temp_end']
X_test = test_data.drop('temp_end', axis=True)
y_test = test_data['temp_end']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Выборки подготовлены корректно

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Для задачи прогнозирования температуры (`temp_end`) на основе предоставленных данных можно рассмотреть две модели: одну классическую и одну современную. В качестве классической модели используем линейную регрессию с регуляризацией - `Ridge`, а в качестве сложной модели модель `LightGBM`.

# %%
robust_scaler = RobustScaler()
X_train_robust = robust_scaler.fit_transform(X_train)
X_test_robust = robust_scaler.transform(X_test)

# Преобразуем массив обратно в DataFrame
X_train_robust = pd.DataFrame(X_train_robust, columns=X_train.columns)
X_test_robust = pd.DataFrame(X_test_robust, columns=X_test.columns)

# %% [markdown]
# #### Ridge

# %%
ridge_model = Ridge(random_state=RANDOM_STATE)
ridge_params = {
    'alpha': [0.01, 0.1, 1, 10, 100],  # Сила регуляризации
    'fit_intercept': [True, False]
}


ridge_search = RandomizedSearchCV(
    ridge_model, ridge_params, n_iter=10, cv=5, scoring='neg_mean_absolute_error', random_state=RANDOM_STATE
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Метрика выбрана верно - МАЕ)

# %%
ridge_search.fit(X_train_robust, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=Ridge(random_state=130125),
#                    param_distributions={'alpha': [0.01, 0.1, 1, 10, 100],
#                                         'fit_intercept': [True, False]},
#                    random_state=130125, scoring='neg_mean_absolute_error')

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера   <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# </b> Ячейка выше не отработала. Прошу проверить работоспособность кода на Платформе Практикума, но не локально - это можно сделать, нажав на панели Платформы Практикума (Jupiter Hub)
#
# `Kernel` и `Restart & Run All`. Исправь, пожалуйста.
#
# В этом требовании есть рациональное зерно. Согласись, если ты будешь презетновать свою работу на чужом компьютере (например руководителю), то не важно, работал ли проект у тебя на комьютере, он должен работать там, где ты будешь его запускать.
#
# Еще при выполнении первых проектов у тебя было ознакомление с "Рекомендациями по выполнению проектов", где сформулировано это правило, инструкция: « Установка окружения — как избежать конфликта версий библиотек»
#
# **Ниже приведу типичные распространенные проблемы, приводящие к падению кода:**
#
# - Если пытаться импортировать библиотеку, которая не установлена в виртуальном окружении Jupiter Hub (или там, где был запущен блокнот), то код с импортами упадет. Закомментированный/отключенный код по установке библиотеки в виртуальном окружении Jupiter Hub равнозначен отсутсвию этой установки - код с импортами упадет. Как и код-ячейка с установкой библиотеки, которая расположена ниже код-ячейки с импортом библиотеки равнозначна отсутсвию этой установки - код с импортами упадет.
# - Облачный Юпитер практикума является коммунальным ресурсом, который может использоваться несколькими пользователями. Окружение (набор библиотек) может быть изменено командами pip каждым пользователем.
# - Раз в несколько часов окружение может быть возвращено в первоначальное состояние, так как вся виртуальная машина перевыпускается, чтобы восстановиться от всех накопившихся экспериментов с pip. Таким образом, в своих блокнотах нужно заботиться об установке нужных версий библиотек.
# - В облачном Юпитере Практикума по умолчанию стоят не самые новые версии библиотек. Поэтому некоторый (более современный) код может не работать. Некоторых библиотек сразу может быть не установлено вообще.
# - В блокнот проекта нужно вставить ячейку с командами обновления библиотек до НУЖНЫХ версий, например:
#     ```
# !pip install -U scikit-learn
# !pip install numpy==...
# !pip install shap
#     ```
# После выполнения этой ячейки нужно перезагрузить ядро с помощью меню Kernel.
# Импорт библиотек можно делать ТОЛЬКО после этого, чтобы изменения могли вступить в силу.
# - Как определить нужную версию? Только на практике можно это понять, по тексту ошибок, по форумам, по опыту, по тому коду, который используется в своем блокноте.
#
# - Также в  инструкции на Платформе есть файл `da_practicum_env.yml`, в котором перечислены версии установленных в Юпитере Практикума библиотек. Посмотри этот файл. Мы - ревьюеры используем именно это окружение.
#
#
# **Если проблема остается непонятной, то советую тебе обратиться за помощью к техподдержке/ преподавателю по проектам, что возможно поможет объяснить ее под другим углом**

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Код изначально создавалься полностью на платформе практикума, локально я не работал с этим проектом. Странно, что у тебя он выполнился с ошибками. Повторный запуск кода на платформе не выдал ошибку. Но на всякий случай добавил ячейку с командами обновления библиотек и убрал параметр normalize из параметров для перебора (я и так в обучении использую тренеровочную выборку со скейлором, нормализация не нужна). Надеюсь это поможет.
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Помогло! Спасибо тебе большое)

# %%
# Лучшие параметры и метрики
print("Лучшие параметры для Ridge:", ridge_search.best_params_)
print("Лучший MAE на кросс-валидации (Ridge):", round(-ridge_search.best_score_, 2))
# Out:
# Лучшие параметры для Ridge: {'fit_intercept': True, 'alpha': 100}
# Лучший MAE на кросс-валидации (Ridge): 7.07

# %% [markdown]
# #### Градиентный бустинг (LightGBM)

# %%
# Градиентный бустинг (LightGBM)
lgbm_model = LGBMRegressor(random_state=RANDOM_STATE)

lgbm_params = {
    'n_estimators': randint(50, 100),
    'max_depth': randint(3, 5),
    'learning_rate': uniform(0.01, 0.3),
    'subsample': uniform(0.5, 0.5),
    'colsample_bytree': uniform(0.5, 0.5),
    'num_leaves': randint(20, 50)
}

lgbm_search = RandomizedSearchCV(
    lgbm_model, lgbm_params, n_iter=10, cv=5, scoring='neg_mean_absolute_error', random_state=RANDOM_STATE
)

# %%
# Обучение моделей
lgbm_search.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2429
# [LightGBM] [Info] Number of data points in the train set: 1390, number of used features: 13
# [LightGBM] [Info] Start training from score 1593.296403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Вывод лучших параметров и метрик
print("Лучшие параметры для LightGBM:", lgbm_search.best_params_)
print("Лучший MAE на кросс-валидации (LightGBM):", round(-lgbm_search.best_score_, 2))
# Out:
# Лучшие параметры для LightGBM: {'colsample_bytree': 0.8985781236871451, 'learning_rate': 0.187863607587935, 'max_depth': 4, 'n_estimators': 81, 'num_leaves': 35, 'subsample': 0.8100063180405515}
# Лучший MAE на кросс-валидации (LightGBM): 7.07

# %% [markdown]
# Ridge-регрессия достигла метрики MAE = 7.07. LightGBM показал немного лучший результат - 7.06, чем Ridge-регрессия, данная модель лучше справляется с нелинейными зависимостями, что делает его более перспективным для дальнейшей работы.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ### Выбор лучшей модели

# %% [markdown]
# LightGBM выбран как наиболее перспективная модель для дальнейшего тестирования.

# %%
# Предсказания на тестовой выборке и расчет метрики MAE
y_pred = lgbm_search.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print("MAE на тестовой выборке (LightGBM):", round(mae, 2))
# Out:
# MAE на тестовой выборке (LightGBM): 6.7

# %%
# Вычисляем R^2
r2 = r2_score(y_test, y_pred)
print("R^2 на тестовой выборке (LightGBM):", round(r2, 4))
# Out:
# R^2 на тестовой выборке (LightGBM): 0.3535

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование модели проведено правильно. Отлично, что дополнительно выведена метрика r2 ради интерпретации

# %%
# Получение важности признаков
best_lgbm_model = lgbm_search.best_estimator_  # Достаем лучшую модель из RandomizedSearchCV
feature_importances = best_lgbm_model.feature_importances_

plt.figure(figsize=(10, 6))
bars = plt.barh(X_train.columns, feature_importances)
plt.title("Feature Importances (LightGBM)")
plt.xlabel("Feature Importances")
plt.ylabel("Features")

# Добавление числовых значений на график
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:.2f}', 
             va='center', ha='left', fontsize=10)

plt.show()

# %%
# Инициализация и обучение константной модели
dummy_model = DummyRegressor(strategy="mean")
dummy_model.fit(X_train, y_train)

# Предсказания на тестовой выборке
y_pred_dummy = dummy_model.predict(X_test)

# Оценка MAE и R^2 для константной модели
mae_dummy = mean_absolute_error(y_test, y_pred_dummy)
r2_dummy = r2_score(y_test, y_pred_dummy)

print("MAE на тестовой выборке (DummyRegressor):", round(mae_dummy, 2))
print("R^2 на тестовой выборке (DummyRegressor):", round(r2_dummy, 4))
# Out:
# MAE на тестовой выборке (DummyRegressor): 8.16
# R^2 на тестовой выборке (DummyRegressor): -0.0001

# %% [markdown]
# Выбранная модель `LightGBM` на тестовой выборке достигла **MAE = 6,65**, что ниже установленного заказчиком условия **MAE ≤ 6,8**, и, таким образом, соответствует поставленной задаче.
#
# Метрика **R² на тестовой выборке = 0,38**, что указывает на то, что модель объясняет 39% дисперсии целевой переменной. Данный результат допустим, поскольку модель демонстрирует адекватное качество предсказаний по целевой метрике MAE.
#
# Анализ важности признаков показал, что наиболее значимым является начальная температура. Также значительное влияние оказывают: объемы материалов `Bulk 14` и `Wire 1`,продолжительность прогрева, продувка газом, продолжительность технологического процесса, и отношение времени нагрева к количеству итераций.
#
# Дополнительно была обучена константная модель `DummyRegressor`, которая показала **MAE = 8,16** и отрицательное значение `R²`. Это подтверждает, что разработанная модель `LightGBM` значительно лучше справляется с задачей и является подходящей для использования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проводишь сравнение своей модели с константной дамми моделью. В каждом проекте при оценке качества модели, имеет смысл проводить такую проверку на адекватность

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что не забываешь оценить важность признаков модели
#
#
# * Дополнительно впоследствии можно заново пересобирать лучшую модель на ограниченном наборе признаков (а не заранее, чтобы была возможность контролировать спад качества), чтобы облегчить ее (может потребоваться заново подобрать параметры). Это может дать небольшой прирост в качестве за счет избавления от зашумленности, главное не переборщить.
#
# - Кроме того вместо встроенной важности можно было бы посмотреть SHAP https://habr.com/ru/articles/428213/, с помощью которого можно было бы также понять характер влияния каждого предиктора

# %% [markdown]
# ### Вывод

# %% [markdown]
# **Описание ключевых шагов решения**:
# - Загрузка данных: Данные были загружены из нескольких файлов и объединены по ключу key.
# - Исследовательский анализ: Проведен анализ данных, выявлены пропуски и выбросы. Удалены аномальные данные.
# - Объединение данных: Данные были объединены в один датафрейм, и на основе корреляционного анализа выбраны наиболее значимые признаки.
# - Предобработка данных: Данные были масштабированы с использованием RobustScaler.
# - Обучение моделей: Были обучены две модели: Ridge-регрессия и LightGBM. Для LightGBM проведен поиск гиперпараметров с использованием RandomizedSearchCV.
# - Оценка моделей: Лучшая модель (LightGBM) была протестирована на тестовой выборке. Достигнута метрика MAE = 6.52, что удовлетворяет условию задачи (MAE ≤ 6.8).
# - Анализ важности признаков: Наиболее значимыми признаками оказались начальная температура, объемы материалов и продолжительность нагрева.
#
# **Лучшая модель**:
# - Модель: LightGBM.
# - Параметры: colsample_bytree=0.60, learning_rate=0.11, max_depth=4, n_estimators=61, num_leaves=31, subsample=0.66.
# - Метрики на тестовой выборке:
# - MAE: 6.52 (удовлетворяет условию задачи).
# - R²: 0.39 (модель объясняет 39% дисперсии целевой переменной).
#
# **Рекомендации для бизнеса**: Модель может быть использована для прогнозирования температуры сплава, что позволит снизить затраты на электроэнергию, обслуживание и ремонты. Наиболее значимыми факторами являются начальная температура, объемы материалов и продолжительность нагрева.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
end_time = time.time()
elapsed_time = end_time - start_time
print('Elapsed time: ', elapsed_time/60, "min")
# Out:
# Elapsed time:  0.6289243817329406 min

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (общий вывод по проекту)  <a class="tocSkip"> </h2>
#
#
# У меня сложилось отличное впечатление о проекте, тебе удалось справиться с таким выпускным проектом. Молодец! Подготовлены данные для анализа, изучены все параметры. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2>  Итоговый комментарий ревьюера 2 (итоговый вывод по проекту) <a class="tocSkip"> </h2>
#
#
# Теперь почти идеально, принимаю работу)
#
# Если хочешь лучше разобраться в специальности, то предлагаю полезные материалы:
# -  <a href="https://academy.yandex.ru/handbook/ml/">Книга от ШАД</a>
#
# - <a href="https://www.youtube.com/playlist?list=PLJ_CMbwA6bT-n1W0mgOlYwccZ-j6gBXqE">Лекции от Andrew Ng</a>
#
# - <a href="https://habr.com/ru/company/ods/blog/322626/">Открытый курс машинного обучения</a>
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a>.
#
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Интерпретировать предсказания моделей поможет  <a href="https://habr.com/ru/post/428213/">SHAP</a>,   <a href="https://towardsdatascience.com/using-shap-values-to-explain-how-your-machine-learning-model-works-732b3f40e137">+ еще ссылка</a>.
# - Интересные способы <a href="https://github.com/DmitrySerg/otus-public/tree/master/OpenLessons/AnomalyDetection">обработки аномалий</a>.
#
#
# С интересом изучал твою работу, код и выводы. Что ещё для дальнейшего улучшения качества/скорости моделирования возможно сделать?
#
# Опишу здесь некоторые идеи:
#
# 1. Качество данных на входе: ещё раз оценить аномалии, пропуски, проверить согласованность временных признаков.
# 2. Генерация новых полезных признаков (features engineering).
# 3. Оптимизация подбора гиперпараметров (OptunaSearchCV, RandomizedSearchCV, BayesSearchCV и т.д.)
# 4. Анализ остатков (разницы между прогнозом и истинным значением таргета): выявить, в каких случаях чаще всего ошибается, а в каких выдает наиболее точный результат...
#
# А главное, мы достигли цели нашего проекта: пройдены основные этапы построения модели регрессии для прогнозирования конечной температуры сплава с учетом ее качества.
#
# Рад был тебе помочь)
#
# Удачи!
#
# </div>
