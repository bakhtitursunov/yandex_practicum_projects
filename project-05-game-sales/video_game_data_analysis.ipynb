# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Baxtiyor :) Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, <b>интерпретации значения p-value - можно повторить недели через две </b>(для профилактики 🤝 )
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# оставил комментарий про расшифровку р-значения, добавил бонус и несколько подсказок

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет,  Baxtiyor  :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# __Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие, а ты попробуешь исправить ее самостоятельно. Но если ты пока не справишься с такой задачей — при следующей проверке я дам более подробную подсказку!__
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Анализ данных видеоигр

# %% [markdown]
# В этом проекте мы проведем анализ данных о видеоиграх для интернет-магазина «Стримчик». Интернет-магазин стремится улучшить свою ассортиментную политику и стратегию продаж, основываясь на выявленных закономерностях в данных о продажах видеоигр в различных регионах мира.
#
# **Цель исследования**
#
# Целью исследования является изучение данных о продажах видеоигр, оценка их популярности и выявление факторов, влияющих на продажи в различных регионах мира. Это поможет интернет-магазину «Стримчик» оптимизировать ассортимент и стратегию продаж.
#
# **Ход исследования**
#
# **Введение**
# В этой части опишим цель и ход исследования.
#
# **Шаг 1: Открытие файла с данными и изучение общей информации.**
# Сначала откроем файл с данными /datasets/games.csv и изучим его содержимое, чтобы понять структуру данных и выявить возможные проблемы, требующие предварительной обработки.
#
# **Шаг 2: Подготовка данных.**
# На этом этапе проведем ряд подготовительных работ с данными:
#
# - Приведем названия столбцов к нижнему регистру.
# - Преобразуем данные в нужные типы и опишем изменения.
# - Обработаем пропуски, объясняя причины их появления и способы обработки. Особое внимание уделим значению 'tbd' в столбце с оценкой пользователей.
# - Добавим новый столбец с суммарными продажами во всех регионах.
#
# **Шаг 3: Исследовательский анализ данных.**
# На данном шаге проведем исследовательский анализ данных:
#
# - Определим, сколько игр выпускалось в разные годы, и оценим важность данных за все периоды.
# - Изучим изменения продаж по платформам, выберем платформы с наибольшими суммарными продажами и построим распределение по годам. Оценим срок появления и исчезновения платформ.
# - Определим актуальный период данных, чтобы построить прогноз на 2017 год, и не будем учитывать данные за предыдущие годы.
# - Проанализируем, какие платформы лидируют по продажам, и выберем несколько потенциально прибыльных платформ.
# - Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам и опишем результаты.
# - Исследуем влияние отзывов пользователей и критиков на продажи внутри одной популярной платформы. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.
# - Сравним выводы с продажами игр на других платформах.
# - Изучим общее распределение игр по жанрам и определим самые прибыльные жанры, выделив жанры с высокими и низкими продажами.
#
# **Шаг 4: Портрет пользователя каждого региона.**
# Определим портрет пользователя для каждого региона (NA, EU, JP):
#
# - Самые популярные платформы (топ-5) и различия в долях продаж.
# - Самые популярные жанры (топ-5) и пояснения по разнице.
# - Влияние рейтинга ESRB на продажи в отдельных регионах.
#
# **Шаг 5: Проверка гипотез.**
# Проверим две гипотезы:
#
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# - Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Для каждой гипотезы:
# - Сформулируем нулевую и альтернативную гипотезы.
# - Выберем критерий для проверки гипотез и объясним выбор.
#
# **Шаг 6: Общий вывод.**
# На основе проведенного анализа и проверенных гипотез напишем общий вывод, который поможет интернет-магазину «Стримчик» оптимизировать свои стратегии продаж видеоигр.
#
# Этот подход позволит нам детально исследовать данные, выявить ключевые закономерности и сформулировать полезные рекомендации для бизнеса.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from scipy import stats as st

# %% [markdown]
# ### Шаг 1: Открытие файла с данными и изучение общей информации

# %%
data = pd.read_csv('/data/games.csv')
display(data.head(20))
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Построение гистограмм
fig, axes = plt.subplots(8, 1, figsize=(10, 30))

axes[0].hist(data['Year_of_Release'].dropna(), bins=40)
axes[0].set_title('Year of Release Distribution')

axes[1].hist(data['NA_sales'].dropna(), bins=100)
axes[1].set_title('North America sales Distribution')

axes[2].hist(data['EU_sales'].dropna(), bins=100)
axes[2].set_title('EU sales Distribution')

axes[3].hist(data['JP_sales'].dropna(), bins=100)
axes[3].set_title('Japan sales Distribution')

axes[4].hist(data['Other_sales'].dropna(), bins=100)
axes[4].set_title('Other regions sales Distribution')

axes[5].hist(data['Critic_Score'].dropna(), bins=50)
axes[5].set_title('Critic Score Distribution')

axes[6].hist(data['User_Score'].dropna(), bins=50)
axes[6].set_title('User Score Distribution')

axes[7].hist(data['Rating'].dropna())
axes[7].set_title('Rating Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# Таблица содержит данные о видеоиграх и состоит из 11 столбцов и 16715 строк. Данные представляют собой информацию о продажах, оценках и других характеристиках видеоигр.
#
# **Основные наблюдения**
# - Пропуски в данных:
#
# Столбец Year_of_Release имеет 269 пропущенных значений.
# Столбец Critic_Score имеет значительное количество пропусков — только 8137 значений из 16715.
# Столбец User_Score также имеет много пропусков — только 10014 значений из 16715.
# Столбец Rating имеет пропуски — только 9949 значений из 16715.
#
# - Типы данных:
#
# Столбец User_Score имеет тип данных object, хотя должен быть числовым. Это связано с наличием некорректных значений, таких как 'tbd' (to be determined), которые нужно обработать.
# Большинство остальных числовых столбцов имеют корректные типы данных float64.
#
# - Продажи по регионам:
#
# Столбцы NA_sales, EU_sales, JP_sales и Other_sales не имеют пропусков и представлены в виде чисел с плавающей запятой (миллионы копий).
#
# - Распределение данных:
#
# Видно, что в данных есть игры с оценками критиков и пользователей, а также с рейтингами ESRB. Однако значительное количество пропусков в этих столбцах требует дополнительной обработки.
#
# **Основные проблемы и дальнейшие шаги**
# - Обработка пропусков: Необходимо определить стратегию обработки пропущенных значений для каждого столбца.
# - Преобразование типов данных: Столбец User_Score нужно привести к числовому типу после обработки некорректных значений ('tbd').
# - Анализ данных: После подготовки данных можно будет приступить к исследовательскому анализу, чтобы выявить закономерности и сделать выводы для интернет-магазина «Стримчик».

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Обзор данных выполнен корректно, применены методы .head(), гистограммы и .info(), промежуточный вывод добавлен, молодец

# %%
# check
# пропущенные значения бары

def pass_value_barh(dfg):
    try:
        (
            (dfg.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)    
        );
        plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
        plt.xlabel('Процент пропусков', fontsize=22)
        plt.ylabel('Столбцы с пропусками')   
        plt.xlim(0, 100)
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, спасибо :)
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# Цвет у шрифта заголовка почти совпадает с цветом у баров
#
# За поворот текста на оси `Y` отвечает параметр `rot`
#
# Можно добавить обозначение оси `Х` (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
#
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         ;
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100, это актуально для некоторых датасетов у которых будет малое кол-во пропусков
#
#         plt.xlim(0, 100)
#
# часть моих новых шрифтов оформлена не совсем корректно 🤝😉

# %% [markdown]
# ### Шаг 2: Подготовка данных.

# %% [markdown]
# #### Обработка названия столбцов

# %%
# приведение названий всех столбцов в нижний регистр
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Работа с типами данных

# %% [markdown]
# Для обработки значения 'tbd' (to be determined) в столбце User_Score лучше всего заменить его на NaN (Not a Number), так как это значение означает, что оценка еще не определена. После этого можно будет конвертировать столбец в числовой тип и при необходимости обрабатывать пропуски.

# %%
# Замена 'tbd' на NaN в столбце User_Score
data['user_score'] = data['user_score'].replace('tbd', np.nan)

# Преобразование столбца User_Score в числовой тип (float)
data['user_score'] = pd.to_numeric(data['user_score'])

data['year_of_release'] = data['year_of_release'].astype('Int64')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
# Проверка результатов
display(data.head(10))
print(data.info())
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# #### Подсчет продаж

# %%
data['sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)
display(data.head(10))
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# #### Обработка пропусков

# %%
# Подсчет количества пропусков
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# sales                 0
# dtype: int64

# %% [markdown]
# Пропуски в столбце 'name' заполнить на основе имеющей информации не возможно, к тому же в этом столбце всего 2 строки с пропуском. Поэтому удалим строки с пропуском по этому столбцу.

# %%
# Удаления строк с пустыми значениями в столбце 'name'
data = data.dropna(subset=['name'])

# %% [markdown]
# Для заполнения пустых строк в столбце 'year_of_release', можем использовать информацию из названия игр. Некоторые игры содержит год выпуска в названиях.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# check
# жизненный срок платформы

# years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
# years_of_life.columns=['min','max']
# years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
# years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)

# %%
# Функция для извлечения года из названия
def extract_year_from_name(name):
    match = re.search(r'\b(19|20)\d{2}\b', name)
    if match:
        return int(match.group(0))
    return None

# Применим функцию к столбцу name
data['extracted_year'] = data['name'].apply(extract_year_from_name)

# Заполним пропущенные значения в year_of_release с помощью extracted_year
data['year_of_release'].fillna(data['extracted_year'], inplace=True)

# Удалим временный столбец
data.drop(columns=['extracted_year'], inplace=True)

# %% [markdown]
# Посмотрим данные по которым остались пропуски в столбце. Для этого группируем данные по платформе и расчитаем какую долю по количеству и продажам в каждой платформе занимают пропуски.

# %%
# Суммарные продажи и пропуски года выпуска по каждой платформе
platform_summary = data.groupby('platform').agg(
    total_sales=('sales', 'sum'),
    missing_year_of_release=('year_of_release', lambda x: x.isna().sum())
).reset_index()

# Подсчет суммарных продаж по пропускам в year_of_release
missing_sales = data[data['year_of_release'].isna()].groupby('platform').agg(
    total_missing_sales=('sales', 'sum')
).reset_index()

# Объединение данных и расчет процента пропусков
platform_summary = platform_summary.merge(missing_sales, on='platform', how='left').fillna(0)
platform_summary['percentage_missing_sales'] = (platform_summary['total_missing_sales'] / platform_summary['total_sales']) * 100

# Вычисление максимального года для каждой платформы
max_year_of_release = data.groupby('platform').agg(
    max_year_of_release=('year_of_release', 'max')
).reset_index()

# Объединение с финальной таблицей
final_summary = platform_summary.merge(max_year_of_release, on='platform', how='left')

# Сортировка по количеству пропусков в столбце year_of_release
final_summary = final_summary.sort_values(by='missing_year_of_release', ascending=False)

# Вывод итоговой таблицы
display(final_summary)
# Out:
#    platform  total_sales  missing_year_of_release  total_missing_sales  \
# 26      Wii       907.51                       34                16.33
# 4        DS       806.12                       29                 3.33
# 28     X360       971.42                       28                10.12
# 16      PS2      1255.77                       27                 8.49
# 17      PS3       939.65                       25                 8.31
# 29       XB       257.74                       18                 5.08
# 0      2600        96.98                       17                10.50
# 13       PC       259.52                       16                 3.41
# 19      PSP       294.05                       14                 3.71
# 7        GC       198.93                       13                 1.90
# 6       GBA       317.85                       11                 4.97
# 2       3DS       259.00                        8                 1.19
# ...

# %% [markdown]
# Как видно по данным, строки с пропусками по столбцу year_of_release не имеют большую долю в продажах в популярных платформах или приходятся на не популярные или старые платформы. Оставим пропуски незаполненными, и при анализе учтем это.

# %%
# check
# жизненный срок платформы

# years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
# years_of_life.columns=['min','max']
# years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
# years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные. Стоит ли применять подобный способ заполнения пропусков. Сможем ли мы корректно учесть особенности выборки
#
#         Рейтинги для жанра Shooter
#         M       553
#         T       340
#         E10+     56
#         E        47
#
# Стоит ли все игры с пропусками для данного жанра переводить в рейтинг для  взрослых?
#
#         553 и 340 имеют примерно одинаковый вес ...

# %% [markdown]
# Заполнение пропусков в столбцах user_score, critic_score, и rating может привести к искажению данных по нескольким причинам:
# - user_score и critic_score: Эти оценки отражают субъективные мнения пользователей и критиков. Заполнение пропусков медианой или любым другим статистическим показателем не учитывает вариабельность и разнообразие этих мнений. В результате заполненные данные могут не соответствовать реальной оценке игры, что приведет к искажению анализа.
# - rating: Мода (наиболее часто встречающееся значение) для рейтингов ESRB может не учитывать специфические особенности отдельных игр. Например, если большинство игр имеют рейтинг 'E' (Everyone), это не значит, что пропущенные значения действительно должны быть 'E'.
# - Заполнение пропусков медианой или модой изменяет распределение данных, делая его менее реальным. Например, распределение оценок может стать более узким, что исказит любые статистические анализы, основанные на этих данных.
#
# Учитывая эти причины, решение оставить пропуски как есть и учитывать их в анализе является более оправданным. Это позволяет сохранить целостность данных и обеспечивает более надежные и точные результаты анализа.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Убрал часть кода заполнением пустых значений в столбцах 'user_score', 'critic_score' и 'rating'. В данном котексте, такое заполнение пропусков приводит к искажению в данных.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты проделал большую работу по восстановлению пропусков. Но иногда пропуск сам по себе является ценной информацией. Для каких стран создавалась система ESRB? Будут ли стараться авторы игр для локального рынка других стран получить рейтинг ESRB?
#
# Оптимальнее на данном проекте использовать категорию «неизвестный рейтинг»

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения
#
#         opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#           return np.nanmean(a, axis, out=out, keepdims=keepdims)
#         /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#           return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, почему ты считаешь подобный способ заполнения пропусков корректным
#
#             # Заполнение по группировке ['genre', 'platform']
#             data['critic_score'] = data.groupby(['genre', 'platform'])['critic_score'].transform(lambda x: x.fillna(x.median()))
#             data['user_score'] = data.groupby(['genre', 'platform'])['user_score'].transform(lambda x: x.fillna(x.median()))
#
#             # Заполнение по группировке ['genre'] для оставшихся пропущенных значений
#             data['critic_score'] = data.groupby('genre')['critic_score'].transform(lambda x: x.fillna(x.median()))
#             data['user_score'] = data.groupby('genre')['user_score'].transform(lambda x: x.fillna(x.median()))
#
#             # Заполнение глобальной медианой для оставшихся пропущенных значений
#             data['critic_score'].fillna(global_median_critic_score, inplace=True)
#             data['user_score'].fillna(global_median_user_score, inplace=True)
#
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Скажи пожалуйста, какое преимущество ты получаешь от заполнения пропусков в числовых колонках на этом проекте, с этой главной задачей?
#
#         Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# Проверим проделанную работу по заполнению пропусков

# %%
# Печатаем информацию о данных для проверки
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     252
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# sales                 0
# dtype: int64

# %% [markdown]
# Итак, мы обработали пропуски в столбцах:
# - удалили строки с пропусками в наименованиях
# - год выпуска заполнили по информации из наименования игр, где это возможно
# - столбцы оценками пользователей и критиков, а также рейтинг оставили с пропусками

# %% [markdown]
# #### Проверка дубликатов

# %%
# Проверка явных дубликатов
data.duplicated().sum()
# Out:
# 0

# %%
# Проверка неявных дубликатов

# Приведение содержимого ключевых столбцов к нижнему регистру
data_lower = data.copy()
data_lower['name'] = data_lower['name'].str.lower()
data_lower['platform'] = data_lower['platform'].str.lower()

# Поиск неполных дубликатов
duplicates = data.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)

# Фильтрация дубликатов
duplicate_rows = data[duplicates]

# Вывод результата
print(duplicate_rows)
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  sales
# 604         0.0         0.23          83.0         5.5      E   2.56
# 16230       0.0         0.00          83.0         5.5      E   0.01

# %%
# Удаление повторяющихся строк, оставляя первую
data = data.drop_duplicates(subset=['name', 'platform', 'year_of_release'], keep='first')

# %% [markdown]
# Проверили данные на наличие дубликатов. Явные дубликаты в данных не найдены, но обнаружен один дубликат по ключевым столбцам 'name', 'platform', 'year_of_release'. Так как оченки и рейтинг у дубликатов был одинаковый, но у второй строки не было почти продаж, мы удалили второе вхождение.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Дубликаты стоит удалять из выборки, которую будем исследовать
#
#         # Удаление повторяющихся строк, оставляя первую
#         data_unique = data.drop_duplicates(subset=['name', 'platform', 'year_of_release'], keep='first')

# %% [markdown]
# Мы провели предобработку данных и подготовили их к исследовательскому анализу: стандартизировали названия столбцов, исправили типы данных, обработали пропуски там где возможно и удалили дубликаты.

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16712 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16712 non-null  object
#  1   platform         16712 non-null  object
#  2   year_of_release  16460 non-null  Int64
#  3   genre            16712 non-null  object
#  4   na_sales         16712 non-null  float64
#  5   eu_sales         16712 non-null  float64
#  6   jp_sales         16712 non-null  float64
#  7   other_sales      16712 non-null  float64
#  8   critic_score     8136 non-null   float64
#  9   user_score       7589 non-null   float64
#  10  rating           9948 non-null   object
#  11  sales            16712 non-null  float64
# dtypes: Int64(1), float64(7), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Датасет не проверен на наличие простых дубликатов
#
# __Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать неполные дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# ### Шаг 3: Исследовательский анализ данных.
#
# #### Выпуск игр по годам

# %%
games_by_years = data.groupby('year_of_release')['name'].count()
print(games_by_years)
# Построение гистограммы
plt.figure(figsize=(10, 6))
plt.bar(games_by_years.index, games_by_years.values)
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр')
plt.title('Количество игр по годам')
plt.show()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     830
# 2003     779
# 2004     764
# 2005     941
# 2006    1008
# 2007    1198
# 2008    1429
# 2009    1427
# 2010    1255
# 2011    1137
# 2012     652
# 2013     545
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %% [markdown]
# График показывает выпуски игр по годам. Как видно со второй половины 1990-х годов количество выпускаемых игр начал стримительно расти. Пик количества выпускаемых игр пришелся на 2005-2010 года. Это можно объяснить факторами экономического роста и роста уровнем жизни, а также развитием цифровых технологий. После 2010 года наблюдается спад в количестве выпускаемых игр. Это может быть связано с насыщением рынка, изменением потребительских предпочтений или появлением новых форм развлечения (например, мобильных приложений).

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график,  все надписи и названия добавлены, молодец

# %% [markdown]
# #### Анализ продаж

# %%
# Группировка данных по платформам и суммирование продаж
platform_sales_total = data.groupby('platform')['sales'].sum().sort_values(ascending=False)
print(platform_sales_total)
# Построение гистограммы
plt.figure(figsize=(15, 6))
plt.bar(platform_sales_total.index, platform_sales_total.values)
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.title('Продажи игр по платформам')
plt.show()
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.64
# Wii      907.51
# DS       806.12
# PS       730.86
# GBA      317.85
# PS4      314.14
# PSP      294.05
# PC       259.52
# 3DS      259.00
# XB       257.74
# GB       255.46
# NES      251.05
# N64      218.68
# SNES     200.04
# GC       198.93
# XOne     159.32
# 2600      96.98
# WiiU      82.19
# PSV       54.07
# SAT       33.59
# GEN       28.35
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: sales, dtype: float64

# %% [markdown]
# Анализ продаж по платформам показывает, что 6 платформ имеют большой отрыв от остальных - PS2, X360, PS3, Wii, DS и PS. Рассмотрим продажи этих платформ по годам и сравним их между собой.

# %%
# Группировка данных по платформам и годам
platform_sales = data.groupby(['platform', 'year_of_release'])['sales'].sum().unstack()

# Выбор платформ с наибольшими суммарными продажами
top_platforms = platform_sales.sum(axis=1).sort_values(ascending=False).head(6).index
top_platform_sales = platform_sales.loc[top_platforms]
display(top_platform_sales)

# Построение распределения по годам
plt.figure(figsize=(10, 6))
for platform in top_platform_sales.index:
    plt.plot(top_platform_sales.columns, top_platform_sales.loc[platform], label=platform)

plt.xlabel('Год выпуска')
plt.ylabel('Суммарные продажи')
plt.title('Распределение продаж по годам для топ-5 платформ')
plt.legend()
plt.show()
# Out:
# year_of_release  1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  \
# platform
# PS2               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# X360              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# PS3               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Wii               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# DS                NaN   NaN   NaN   NaN   NaN  0.02   NaN   NaN   NaN   NaN
# PS                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# year_of_release  ...    2007    2008    2009    2010    2011    2012    2013  \
# platform         ...
# PS2              ...   75.99   53.90   26.40    5.64    0.45     NaN     NaN
# X360             ...   95.42  135.26  120.29  170.03  143.89   99.74   88.58
# PS3              ...   73.19  118.52  130.93  142.17  156.78  107.35  113.25
# Wii              ...  152.77  171.32  206.97  127.95   59.65   21.71    8.59
# ...

# %% [markdown]
# На графике видет пустое поле слева, указывающий на аномалии данных. Как видно из таблицы у платформы DS есть аномальные значение в 1885 г. Удалим стоку, для исправления данных.

# %%
# Поиск индексов строк, которые нужно удалить
indices_to_drop = data[(data['platform'] == 'DS') & (data['year_of_release'] == 1985)].index

# Удаление строк
data = data.drop(indices_to_drop)

# Проверка
# Группировка данных по платформам и годам
platform_sales = data.groupby(['platform', 'year_of_release'])['sales'].sum().unstack()

# Выбор платформ с наибольшими суммарными продажами
top_platforms = platform_sales.sum(axis=1).sort_values(ascending=False).head(6).index
top_platform_sales = platform_sales.loc[top_platforms]

# Построение распределения по годам
plt.figure(figsize=(10, 6))
for platform in top_platform_sales.index:
    plt.plot(top_platform_sales.columns, top_platform_sales.loc[platform], label=platform)

plt.xlabel('Год выпуска')
plt.ylabel('Суммарные продажи')
plt.title('Распределение продаж по годам для топ-5 платформ')
plt.legend()
plt.show()

# %% [markdown]
# На основе этого графика можно сделать вывод что новые платформы обычно появляются примерно каждые 5-10 лет и пик продаж новой платформы наблюдается через несколько лет после её выпуска.
# Старые платформы начинают уступать популярность новым примерно через 10 лет. Продажи старых платформ постепенно снижаются, когда пользователи переходят на более новые консоли.
#
# На основе графика, актуальный период для анализа можно выбрать начиная с 2013 года. Этот период включает последние годы активности платформ, что позволяет лучше понять текущие тренды и сделать прогноз на 2017 год. Платформы, которые активно продавались в последние годы, вероятно, будут продолжать приносить прибыль. Рассмотрим продажи за этот период по платформам.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %%
# Фильтрация данных за период после 2010 года
recent_sales_data = data[data['year_of_release'] > 2012]

# Группировка данных по платформам и суммирование продаж
platform_sales_total = recent_sales_data.groupby('platform')['sales'].sum().sort_values(ascending=False)
print(platform_sales_total)
# Построение гистограммы
plt.figure(figsize=(15, 6))
plt.bar(platform_sales_total.index, platform_sales_total.values)
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.title('Продажи игр по платформам')
plt.show()
# Out:
# platform
# PS4     314.14
# PS3     181.43
# XOne    159.32
# 3DS     143.25
# X360    136.80
# WiiU     64.63
# PC       39.78
# PSV      32.99
# Wii      13.66
# PSP       3.50
# DS        1.54
# Name: sales, dtype: float64

# %% [markdown]
# Анализ продаж по платформам  за 2013-2016 годы показывает, что Sony и Microsoft являются лидерами. Самыми популярными платформами являются PS4, PS3, XOne, 3DS и X360. Также, платформа PC оставалась популярной достаточно долгое время и продолжает быть активной, для дальныейшего анализа включим топ-7 платформ. Рассмотрим продажи этих платформ и выявим платформы с растущими и падающими продажами.

# %%
# Группировка данных по платформам и годам
platform_sales_by_year = recent_sales_data.groupby(['platform', 'year_of_release'])['sales'].sum().unstack()

# Выбор платформ с наибольшими суммарными продажами
top_platforms = platform_sales_total.head(7).index
top_platform_sales_by_year = platform_sales_by_year.loc[top_platforms]
print(top_platform_sales_by_year)
# Out:
# year_of_release    2013    2014    2015   2016
# platform
# PS4               25.99  100.00  118.90  69.25
# PS3              113.25   47.76   16.82   3.60
# XOne              18.96   54.07   60.14  26.15
# 3DS               56.57   43.76   27.78  15.14
# X360              88.58   34.74   11.96   1.52
# WiiU              21.65   22.03   16.35   4.60
# PC                12.73   13.28    8.52   5.25

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         recent_sales_data = data[data['year_of_release'] > 2010]

# %%
# Построение распределения по годам для топ-5 платформ
plt.figure(figsize=(10, 6))
for platform in top_platform_sales_by_year.index:
    plt.plot(top_platform_sales_by_year.columns, top_platform_sales_by_year.loc[platform], label=platform)

plt.xlabel('Год выпуска')
plt.ylabel('Суммарные продажи')
plt.title('Распределение продаж по годам для топ-5 платформ')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Можно подправить подписи оси х, в виде целых 2014, 2015 ...,
#
# искать тему Ticks and ticklabels
#
# https://matplotlib.org/stable/tutorials/text/text_intro.html
#
# или
#
# https://dev-gang.ru/article/izmenenie-czastoty-tikov-v-matplotlib-k5x1kznn39/?ysclid=lcp5si8pky848462627

# %%
# Определение растущих и падающих платформ
growth_trend = top_platform_sales_by_year[2015] - top_platform_sales_by_year[2013]
growing_platforms = growth_trend[growth_trend > 0].index
declining_platforms = growth_trend[growth_trend < 0].index

print("Растущие платформы:", growing_platforms)
print("Падающие платформы:", declining_platforms)
# Out:
# Растущие платформы: Index(['PS4', 'XOne'], dtype='object', name='platform')
# Падающие платформы: Index(['PS3', '3DS', 'X360', 'WiiU', 'PC'], dtype='object', name='platform')

# %% [markdown]
# Про графику видно, что платформы PS4 и XOne имеют растущий тренд по продажам, а остальные платформы падают. 2016 году продажи по всем платформам ниже предыдущих годов, это связано с неполными продажами в 2016 году.
#
# Так как все 7 платформы являются лидерами по продажам игр в актуальном периоде, можно указать их потенциально прибыльными, несмотря на падающие продажи, так как продажи во всех указанных платформах достаточно высокие.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# X360 и PS3 уже исполнилось 11 лет и они с малой вероятностью станут перспективными или сохранят продажи в 2017 году

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит уверенно утверждать перечень перспективных платформ
#
#
# даже  на падающих продажах можно заработать, когда объем составляет около 15-20 млн. копий, как например с 3DS
#
# 30-тилетняя история персональных компьютеров говорит, что игры для PC можно включить в рекомендацию

# %%
# Построение графика "ящик с усами"
plt.figure(figsize=(12, 8))
sns.boxplot(x='platform', y='sales', data=recent_sales_data)
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи')
plt.title('Глобальные продажи игр по платформам')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит развернуть надписи на оси Х в горизонтальное положение

# %%
# Построение графика "ящик с усами"
plt.figure(figsize=(12, 8))
sns.boxplot(x='platform', y='sales', data=recent_sales_data)
plt.xlabel('Платформа')
plt.ylabel('Глобальные продажи')
plt.ylim(0, 2)
plt.title('Глобальные продажи игр по платформам')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# На основе анализа распределения продаж с помощью боксплота, можно сделать следующие выводы:
# - большинство игр для каждой платформы имеют относительно низкие продажи, что видно по плотности данных в нижней части ящиков
# - выбросы указывают на отдельные игры с очень высокими продажами, которые значительно превышают медианные значения
# - количество выбросов указывает на то, что некоторые игры значительно превосходят другие по продажам. Это может свидетельствовать о наличии хитов в платформах, которые сильно влияют на общие продажи платформы.
# - популярные платформы с высокими продажами имеют больше выбросов, и достаточно далеко расположенных от верхних "усов".
# - платформы с высокой медианой имеют более высокие средние продажи игр. Это означает, что как минимум половина игр на этих платформах продается лучше, чем на других.
# - у платформ Microsoft медиана выше чем у платформ Sony, что может указывать что у Sony продает больше отдельные хиты, и большинство остальных игр продаются меньше, тогда как в платформах Microsoft продажи игр распределены более равномерно.
# - платформы с широким IQR имеют значительное разнообразие в продажах игр. Это может означать, что на платформе есть как очень успешные, так и менее успешные игры. Платформы с узким IQR имеют более однородные продажи игр, что может указывать на стабильность.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)
#
# https://stackoverflow.com/questions/22028064/matplotlib-boxplot-without-outliers

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# К сожалению, на этих графиках видны только выбросы, и совсем не видны медиана и 75% квантиль, плюс тяжело сравнивать разрозненные ящики между собой
#
# __Для более обоснованных выводов  стоит  перерисовать диаграмму размаха__, на актуальной выборке:
#
# + используя параметр by, который позволит сравнить ящики всех платформ на одном виде; если используется библиотека seaborn, то у нее свой параметр, который позволяет разделить выборку по платформам
# + в двух масштабах:
#     + 100%
#     + и где будет отображена только нижняя часть boxplot-ов
#
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки
#
# оставил ссылку на примеры
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html?highlight=boxplo#pandas.DataFrame.boxplot
#
#
# для изменения масштаба стоит применить ylim()
#
# https://matplotlib.org/stable/gallery/pyplots/axline.html#sphx-glr-gallery-pyplots-axline-py
#
# https://www.codecamp.ru/blog/matplotlib-set-axis-range/?ysclid=lkhae1u0s0375749132

# %% [markdown]
# #### Анализ платформ лидеров - PS4, PS3 и XOne

# %%
selected_platforms = ['PS3', 'PS4', 'XOne']

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>. ⬇⬇
#
# </div>

# %%
for platform in selected_platforms:
    platform_data = data[data['platform'] == platform]
    plt.figure(figsize=(15, 6))
    plt.plot(platform_data['user_score'], platform_data['sales'], 'o')
    plt.xlabel('Оценка пользователей')
    plt.ylabel('Продажи')
    plt.title(f'Зависимость продаж от оценки пользователей на платформе {platform}')
    plt.show()
    print(f'Коэффицент корреляции между оценкой пользователей и продажам игры на платформе {platform}:', 
          platform_data['user_score'].corr(platform_data['sales']))
# Out:
# Коэффицент корреляции между оценкой пользователей и продажам игры на платформе PS3: 0.12620720462052887
# Коэффицент корреляции между оценкой пользователей и продажам игры на платформе PS4: -0.031957110204556376
# Коэффицент корреляции между оценкой пользователей и продажам игры на платформе XOne: -0.06892505328279414

# %% [markdown]
# На предоставленных диаграммах рассеяния показана зависимость между оценками пользователей и продажами игр на платформах PS3, PS4 и Xbox One. На всех трех платформах нет сильной зависимости между оценками пользователей и продажами игр.

# %%
for platform in selected_platforms:
    platform_data = data[data['platform'] == platform]
    plt.figure(figsize=(15, 6))
    plt.plot(platform_data['critic_score'], platform_data['sales'], 'o')
    plt.xlabel('Оценка критиков')
    plt.ylabel('Продажи')
    plt.title(f'Зависимость продаж от оценки критиков на платформе {platform}')
    plt.show()
    print(f'Коэффицент корреляции между оценкой критиков и продажам игры на платформе {platform}:', 
          platform_data['critic_score'].corr(platform_data['sales']))
# Out:
# Коэффицент корреляции между оценкой критиков и продажам игры на платформе PS3: 0.43337268693947595
# Коэффицент корреляции между оценкой критиков и продажам игры на платформе PS4: 0.40656790206178095
# Коэффицент корреляции между оценкой критиков и продажам игры на платформе XOne: 0.4169983280084017

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#        PS3: 0.43243156856420634

# %% [markdown]
# На предоставленных диаграммах рассеяния показана зависимость между оценками критиков и продажами игр на платформах PS4, Xbox One и PC.
# На всех трех платформах существует положительная корреляция между оценками критиков и продажами игр, что указывает на то, что высокие оценки критиков могут способствовать увеличению продаж. Однако, корреляция не является очень сильной, что говорит о том, что помимо оценок критиков, на продажи влияют и другие факторы.
#
# В целом, оценки критиков оказывают большее влияние на продажи игр, чем оценки пользователей, особенно на современных консолях. Однако, для полного понимания факторов, влияющих на продажи игр, необходимо учитывать и другие аспекты, такие как маркетинг, эксклюзивность игр, отзывы пользователей и т.д.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит выполнить исследование зависимости продаж от оценок пользователей и критиков по платформам конкурентам — рассмотреть в этом разделе отдельно две-три платформы
#
#         ps4, xone
#
# Выводы, сделанные на основе расчетов по нескольким платформам выглядят "весомей" и убедительней

# %% [markdown]
# #### Анализ по жанрам

# %%
# Построение диаграммы размаха для продаж по жанрам
plt.figure(figsize=(14, 8))
sns.boxplot(x='genre', y='sales', data=recent_sales_data)
plt.xticks(rotation=45)
plt.xlabel('Жанр')
plt.ylabel('Продажи')
plt.title('Распределение продаж по жанрам')
plt.show()

# Расчет медианных продаж по жанрам
median_sales_by_genre = recent_sales_data.groupby('genre')['sales'].median().sort_values(ascending=False)
print("\nМедианные продажи по жанрам:")
print(median_sales_by_genre)

# Построение диаграммы размаха для продаж по жанрам без выбросов
plt.figure(figsize=(14, 8))
sns.boxplot(x='genre', y='sales', data=recent_sales_data)
plt.xticks(rotation=45)
plt.ylim(0, 3.5)
plt.xlabel('Жанр')
plt.ylabel('Продажи')
plt.title('Распределение продаж по жанрам')
plt.show()
# Out:
# Медианные продажи по жанрам:
# genre
# Shooter         0.450
# Sports          0.240
# Platform        0.225
# Role-Playing    0.125
# Fighting        0.125
# Racing          0.120
# Action          0.110
# Simulation      0.100
# Misc            0.100
# Strategy        0.080
# Puzzle          0.060
# Adventure       0.030
# Name: sales, dtype: float64

# %% [markdown]
# Графики размаха по жанрам позволяют увидеть общую картину распределения продаж по жанрам, включая выбросы.
#
# Самые прибыльные жанры:
# - Shooter: Наибольший размах, множество выбросов, и высокая медиана продаж. Это указывает на то, что шутеры часто продаются очень хорошо и имеют много игр с высокими продажами.
# - Sports: Тоже имеет высокий размах и большое количество выбросов, что указывает на высокие продажи в этом жанре.
# - Action: Также имеет значительное количество выбросов, хотя медиана ниже, чем у шутеров и спортивных игр.
# - Misc: Жанр с большим размахом и значительным количеством выбросов, что говорит о разнообразии и высоких продажах некоторых игр.
#
# Жанры с низкими продажами:
# - Puzzle (головоломки) и Adventure (приключения): Эти жанры имеют низкие медианные продажи и практически не имеют выбросов с высокими значениями продаж.
# - Strategy (стратегии): Низкая медиана и незначительное количество выбросов.
#
# Сравнение медианных продаж:
# - Shooter имеет самую высокую медиану (0.45), что подтверждает его высокую прибыльность.
# - Sports и Platform (платформеры) также имеют высокие медианные продажи (0.24 и 0.225 соответственно), показывая стабильность и популярность этих жанров.
# - Role-Playing (ролевые игры) и Fighting (файтинги) имеют одинаковую медиану (0.125), что указывает на среднюю прибыльность.
#
# Стабильность продаж:
# - Shooter и Sports демонстрируют не только высокие медианные продажи, но и широкий диапазон успешных игр.
# - Misc имеет значительное количество успешных игр, но меньше стабильности в медианных значениях по сравнению с шутерами и спортивными играми.
# - Puzzle и Adventure имеют самую низкую медиану (0.06 и 0.03 соответственно), что указывает на низкие и менее стабильные продажи.
#
# Общие выводы:
# Самые прибыльные жанры: Шутеры и спортивные игры явно лидируют по продажам и количеству успешных игр. Эти жанры обладают высокой медианой и значительным количеством выбросов, указывающих на успешные игры.
# Жанры с высокой стабильностью: Шутеры и спортивные игры также демонстрируют стабильные высокие продажи, что делает их надежными в плане инвестиций.
# Жанры с низкими продажами: Головоломки и приключения демонстрируют самые низкие медианные продажи и низкую стабильность, что делает их менее привлекательными с точки зрения прибыли.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не стоит забывать и про экшен, у этого жанра сумма продаж довольно значительная

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# ### Шаг 4: Портрет пользователей по регионам
#
# #### Популярные платформы пользователей по регионам

# %%
# Создание списка регионов
regions = ['na_sales', 'eu_sales', 'jp_sales']

# Создание графика
fig, axes = plt.subplots(1, 3, figsize=(15, 8))

# Добавление в график данных по регионам
for i, region in enumerate(regions):
    # Суммируем продажи по платформам и сортируем
    sales = recent_sales_data.groupby('platform')[region].sum().sort_values(ascending=False)
    
    # Оставляем 5 крупнейших платформ
    top_5 = sales.head(5)
    
    # Остальные объединяем в "Others"
    others = sales[5:].sum()
    sales = top_5.append(pd.Series(others, index=['Others']))
    
    # Рассчитываем доли
    total_sales = sales.sum()
    sales_share = (sales / total_sales) * 100
    
    # Построение пай-чарта
    axes[i].pie(sales_share, labels=sales_share.index, autopct='%1.1f%%', startangle=140)
    axes[i].set_title(f'Процентное соотношение платформ в {region[:2]}')
    
    # Вывод топ 5 платформ
    print(f"Топ 5 платформ в {region[:2]}:")
    print(top_5)
    print()

# Настройка общего заголовка
fig.suptitle('Процентное соотношение платформ по регионам', fontsize=16)

# Отображение графика
plt.tight_layout()
plt.show()
# Out:
# Топ 5 платформ в na:
# platform
# PS4     108.74
# XOne     93.12
# X360     81.66
# PS3      63.50
# 3DS      38.20
# Name: na_sales, dtype: float64
#
# Топ 5 платформ в eu:
# platform
# PS4     141.09
# PS3      67.81
# XOne     51.59
# X360     42.52
# 3DS      30.96
# Name: eu_sales, dtype: float64
#
# Топ 5 платформ в jp:
# platform
# 3DS     67.81
# PS3     23.35
# PSV     18.59
# PS4     15.96
# WiiU    10.88
# Name: jp_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит снизить высоту графика, чтобы сократить разрыв между общим заголовком и самими графиками

# %% [markdown]
# На основе сравнения продаж платформ по регионам можно сделать следующие выводы:
# - PS3 и Wii входят в топ-5 во всех регионах, что говорит о их универсальной популярности.
# - Все три региона имеют значительную долю продаж, распределенную между несколькими платформами, с явно выраженными лидерами.
# - Others в каждом регионе занимают различную долю, что свидетельствует о разнообразии используемых платформ вне топ-5.
# - Северная Америка: X360 лидирует по продажам, в то время как в других регионах она менее популярна.
# - Европа: PS3 занимает более чем треть рынка, что значительно выше по сравнению с другими регионами.
# - Япония: DS доминирует на рынке, занимая почти половину продаж, что не наблюдается ни в Северной Америке, ни в Европе.
#
# В целом, графики показывают, что рынок видеоигр сильно зависит от региона, с явными предпочтениями в разных частях мира.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 2011 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# #### Популярные жанры пользователей по регионам

# %%
# Создание графика
fig, axes = plt.subplots(1, 3, figsize=(15, 8))

# Добавление в график данных по регионам
for i, region in enumerate(regions):
    # Суммируем продажи по жанрам и сортируем
    sales = recent_sales_data.groupby('genre')[region].sum().sort_values(ascending=False)
    
    # Оставляем 5 крупнейших жанров
    top_5 = sales.head(5)
    
    # Остальные объединяем в "Others"
    others = sales[5:].sum()
    sales = top_5.append(pd.Series(others, index=['Others']))
    
    # Рассчитываем доли
    total_sales = sales.sum()
    sales_share = (sales / total_sales) * 100
    
    # Построение пай-чарта
    axes[i].pie(sales_share, labels=sales_share.index, autopct='%1.1f%%', startangle=140)
    axes[i].set_title(f'Процентное соотношение жанров в {region[:2]}')
    
    # Вывод топ 5 жанров
    print(f"Топ 5 жанров в {region[:2]}:")
    print(top_5)
    print()

# Настройка общего заголовка
fig.suptitle('Процентное соотношение жанров по регионам', fontsize=16)

# Отображение графика
plt.tight_layout()
plt.show()
# Out:
# Топ 5 жанров в na:
# genre
# Action          126.11
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.49
# Name: na_sales, dtype: float64
#
# Топ 5 жанров в eu:
# genre
# Action          118.38
# Shooter          87.86
# Sports           60.52
# Role-Playing     36.97
# Racing           20.19
# Name: eu_sales, dtype: float64
#
# Топ 5 жанров в jp:
# genre
# Role-Playing    51.04
# Action          40.49
# Misc             9.20
# Fighting         7.65
# Shooter          6.61
# Name: jp_sales, dtype: float64

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br /> По умолчанию этот метод выводит 5 строк, 5-ку можно не писать
#
#             .head(5)

# %% [markdown]
# На основе сравнения продаж жанров по регионам можно сделать следующие выводы:
# - Action и Role-Playing входят в топ-5 жанров во всех регионах, что говорит об их универсальной популярности.
# - Жанры Shooter и Action имеют значительную долю рынка в Северной Америке и Европе.
# - Северная Америка и Европа: Жанр Shooter занимает лидирующие позиции, в то время как в Японии он значительно менее популярен.
# - Япония: Жанр Role-Playing доминирует на рынке, занимая почти треть всех продаж, что не наблюдается ни в Северной Америке, ни в Европе.
# - Доля Others в Японии значительно выше (18.3%), чем в других регионах, что свидетельствует о большем разнообразии предпочтений среди японских игроков.
#
# В целом, Северная Америка и Европа предпочитают динамичные жанры, такие как Shooter и Action.
# Японский рынок ориентирован на жанры Role-Playing и Action, при этом имеет более широкий спектр жанров, представленных в категории Others.

# %% [markdown]
# #### Взаимосвязь рейтинга ESRB с продажами по регионам

# %%
# Построение столбчатых диаграмм
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Анализ по рейтингам ESRB
for i, region in enumerate(regions):
    sales_by_rating = recent_sales_data.groupby('rating')[region].sum().sort_values(ascending=False)
    
    axes[i].bar(sales_by_rating.index, sales_by_rating)
    axes[i].set_title(f'Продажи по рейтингам ESRB в {region[:2]}')
    axes[i].set_xlabel('Рейтинг ESRB')
    axes[i].set_ylabel('Продажи')
    
    # Вывод ТОП-5 рейтингов по продажам
    top_ratings = sales_by_rating.head(5)
    print(f"ТОП-5 рейтингов ESRB в {region[:2]}:")
    print(top_ratings)
    print()

plt.show()
# Out:
# ТОП-5 рейтингов ESRB в na:
# rating
# M       165.27
# E        79.05
# E10+     54.24
# T        49.79
# Name: na_sales, dtype: float64
#
# ТОП-5 рейтингов ESRB в eu:
# rating
# M       145.57
# E        83.36
# E10+     42.69
# T        41.95
# Name: eu_sales, dtype: float64
#
# ТОП-5 рейтингов ESRB в jp:
# rating
# T       20.59
# E       15.14
# M       14.11
# E10+     5.89
# Name: jp_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# На основе данных можно сделать следующие выводы о влиянии рейтинга ESRB на продажи видеоигр в различных регионах:
#
# В Северной Америке игры с рейтингом “M” (Mature) занимают наибольшую долю рынка, с продажами в 165.27 миллионов. За ними следуют игры с рейтингом “E” (Everyone) с продажами в 79.05 миллионов, “E10+” (Everyone 10 and older) с 54.24 миллионов и “T” (Teen) с 49.79 миллионов. Это указывает на то, что взрослые игры пользуются наибольшей популярностью в этом регионе.
#
# В Европе также наблюдается доминирование игр с рейтингом “M” с продажами в 145.57 миллионов. Однако игры с рейтингом “E” занимают второе место с 83.36 миллионов, что выше, чем в Северной Америке. Игры с рейтингами “E10+” и “T” имеют продажи в 42.69 и 41.95 миллионов соответственно. Это показывает, что в Европе также предпочитают взрослые игры, но игры для всех возрастов также имеют значительную долю рынка.
#
# В Японии ситуация отличается: игры с рейтингом “T” занимают наибольшую долю рынка с продажами в 20.59 миллионов. За ними следуют игры с рейтингом “E” с 15.14 миллионов и “M” с 14.11 миллионов. Игры с рейтингом “E10+” имеют наименьшие продажи — 5.89 миллионов. Это указывает на то, что в Японии более популярны игры для подростков, а не для взрослых.
#
# Вывод:
# Рейтинг ESRB значительно влияет на продажи видеоигр в различных регионах. В Северной Америке и Европе наибольшую долю рынка занимают игры с рейтингом “M”, что указывает на предпочтение взрослых игр. В Японии же более популярны игры с рейтингом “T”, что может быть связано с культурными особенностями и предпочтениями потребителей в этом регионе.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит пересчитать ТОП-5, сейчас мы нашли продажи по каждому рейтингу. В проекте мы ищем долю рынка, которые занимают рейтинги, а для этого смотрим на сумму продаж по каждому рейтингу

# %% [markdown]
# Общий вывод:
# Анализ данных о продажах видеоигр показывает, что предпочтения пользователей сильно зависят от региона. Платформы и жанры, популярные в одном регионе, могут быть менее востребованы в другом. Рейтинг ESRB также оказывает значительное влияние на продажи, причем в разных регионах предпочтения по возрастным категориям игр различаются.
#
# В Северной Америке пользователи предпочитают динамичные и интенсивные игры, такие как шутеры и экшены. Они часто выбирают платформы X360 и PS3. Взрослые игры с рейтингом "M" пользуются наибольшей популярностью.
#
# Европейские пользователи также предпочитают динамичные жанры, такие как шутеры и экшены. Платформа PS3 занимает значительную долю рынка. Взрослые игры популярны, но игры для всех возрастов также имеют значительную аудиторию.
#
# В Японии пользователи предпочитают жанры ролевых игр и экшенов. Платформа DS доминирует на рынке. Игры для подростков с рейтингом "T" наиболее популярны, что может быть связано с культурными особенностями и предпочтениями японских игроков.

# %% [markdown]
# ### Шаг 5: Проверка гипотез
#
# #### Гипотеза 1: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Для проверки гипотезы проведем t-test:
#
# - Нулевая гипотеза (H0): Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# - Альтернативная гипотеза (H1): Средние пользовательские рейтинги платформ Xbox One и PC разные.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
xone = recent_sales_data[recent_sales_data['platform'] == 'X360']['user_score'].dropna()
pc = recent_sales_data[recent_sales_data['platform'] == 'PC']['user_score'].dropna()
print(xone.head())
print(pc.head())
# Out:
# 23     8.1
# 60     2.6
# 263    4.9
# 271    4.2
# 380    5.6
# Name: user_score, dtype: float64
# 458     3.9
# 1095    7.9
# 1351    2.2
# 1437    6.0
# 1530    5.4
# Name: user_score, dtype: float64

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %%
alpha = 0.05

results = st.ttest_ind(xone, pc)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.13666236270896462
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Для гипотезы о равенстве средних пользовательских рейтингов платформ Xbox One и PC, p-значение оказалось выше порогового уровня значимости (0.05), что не позволило отвергнуть нулевую гипотезу. Это означает, что у нас нет статистически значимых доказательств того, что пользовательские рейтинги на этих платформах различаются.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.05337608984266452

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В статистике p-значение (или уровень значимости) помогает определить, насколько сильны доказательства против нулевой гипотезы. p-значение = 0.05337608984266452 - значение чуть выше 0.05, поэтому мы не можем отвергнуть нулевую гипотезу на уровне значимости 0.05. Это означает, что у нас недостаточно доказательств, чтобы утверждать, что существует значимая разница между пользовательскими оценками для платформ X360 и PC.
#
# При пересчете нового актуального периода и исправления заполнения пустых ячений, P-value значительно выше.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# #### Гипотеза 2: Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Для проверки гипотезы проведем t-test:
#
# - Нулевая гипотеза (H0): Средние пользовательские рейтинги жанров Action и Sports одинаковые.
# - Альтернативная гипотеза (H1): Средние пользовательские рейтинги жанров Action и Sports разные.

# %%
action = recent_sales_data[recent_sales_data['genre'] == 'Action']['user_score'].dropna()
sports = recent_sales_data[recent_sales_data['genre'] == 'Sports']['user_score'].dropna()
print(action.head())
print(sports.head())
# Out:
# 16     8.2
# 23     8.1
# 42     8.3
# 149    9.1
# 165    7.9
# Name: user_score, dtype: float64
# 77     4.3
# 94     5.0
# 126    4.3
# 143    5.7
# 264    4.5
# Name: user_score, dtype: float64

# %%
results = st.ttest_ind(action, sports)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 7.68963684307543e-28
# Отвергаем нулевую гипотезу

# %% [markdown]
# Для гипотезы о равенстве средних пользовательских рейтингов жанров Action и Sports, p-значение оказалось значительно ниже порогового уровня значимости (0.05), что позволило отвергнуть нулевую гипотезу. Это указывает на то, что средние пользовательские рейтинги жанров Action и Sports статистически значимо различаются.

# %% [markdown]
# ### Общий вывод:

# %% [markdown]
# В ходе исследования исторических данных о продажах игр, оценки пользователей и экспертов, жанры и платформы пользователей сервиса , были выполнены следующие этапы:
#
# 1. Открытие файла и начальная оценка данных
#
# На этом этапе была проведена предварительная оценка структуры и содержания данных, определены основные параметры и их типы.
#
# 2. Подготовка данных
#
# - Наименование столбцов были приведены в единый стандарт
# - Исправлены типы значений
# - Обработаны пропуски
# - Обработаны дубликаты
# - Добавлен столбец с суммарными продажами по миру
#
# 3. Исследовательский анализ данных
#
# В рамках исследовательского анализа были изучены и сделаны предварительные выводы по следующим:
# - Выпуск игр по годам
# Данные показали, что со второй половины 1990-х годов количество выпускаемых игр начал стремительно расти. Пик количества выпускаемых игр пришелся на 2005-2010 года. Это можно объяснить факторами экономического роста и роста уровнем жизни, а также развитием цифровых технологий. После 2010 года наблюдается спад в количестве выпускаемых игр. Это может быть связано с насыщением рынка, изменением потребительских предпочтений или появлением новых форм развлечения (например, мобильных приложений).
# - Анализ продаж
# Анализ продаж показал, что новые платформы обычно появляются примерно каждые 5-10 лет и пик продаж новой платформы наблюдается через несколько лет после её выпуска. Старые платформы начинают уступать популярность новым примерно через 10 лет. Продажи старых платформ постепенно снижаются, когда пользователи переходят на более новые консоли.
# Также, на основе изучения данных был определен актуальный период с 2013-го 2016й. Изучение актуального периода показал, что платформы PS2, X360, PS3, Wii и DS имеют большой отрыв по продажам от остальных платформ. Также, платформа PC оставалась популярной достаточно долгое время и продолжает быть активной.
# Мы также изучили популярные платформы, и пришли к выводу, что большинство игр для каждой платформы имеют относительно низкие продажи, а некоторые игры значительно превосходят другие по продажам - это может свидетельствовать о наличии хитов в платформах, которые сильно влияют на общие продажи платформы.
# - Анализ платформ PS3, PS4, XOne
# Мы изучили взаимосвязи между отзывами и продажами данных платформ. Анализ показал, что оценки критиков оказывают большее влияние на продажи игр, чем оценки пользователей, особенно на современных консолях. Однако, для полного понимания факторов, влияющих на продажи игр, необходимо учитывать и другие аспекты, такие как маркетинг, эксклюзивность игр, отзывы пользователей и т.д.
# - Анализ по жанрам
# По анализу данных по жанрам, можно сделать следующие выводы:
# •	Шутеры и спортивные игры явно лидируют по продажам и количеству успешных игр. Эти жанры обладают высокой медианой и значительным количеством выбросов, указывающих на успешные игры.
# •	Шутеры и спортивные игры также демонстрируют стабильные высокие продажи, что делает их надежными в плане инвестиций.
# •	Головоломки и приключения демонстрируют самые низкие медианные продажи и низкую стабильность, что делает их менее привлекательными с точки зрения прибыли.
#
# 4. Портрет пользователей по регионам
#
# Для изучения пользователей по регионам, изучили топ-5 платформ и жанров, а также влияние рейтинга ESRB на продажи.
# - По данным топ-5 платформ по регионам можно сделать вывод, что рынок видеоигр сильно зависит от региона, с явными предпочтениями в разных частях мира.
# - По данным топ-5 жанров по регионам можно сделать вывод, что Северная Америка и Европа предпочитают динамичные жанры, такие как Shooter и Action. Японский рынок ориентирован на жанры Role-Playing и Action, при этом имеет более широкий спектр жанров, представленных в категории Others.
# - Анализ взаимосвязи рейтинга ESRB с продажами по регионам показал значительно влияние на продажи видеоигр в различных регионах. В Северной Америке и Европе наибольшую долю рынка занимают игры с рейтингом “M”, что указывает на предпочтение взрослых игр. В Японии же более популярны игры с рейтингом “T”, что может быть связано с культурными особенностями и предпочтениями потребителей в этом регионе.
# Таким образом, можно сделать вывод, что портрет пользователя по регионам таков:
# •	В Северной Америке пользователи предпочитают динамичные и интенсивные игры, такие как шутеры и экшены. Они часто выбирают платформы X360 и PS3. Взрослые игры с рейтингом "M" пользуются наибольшей популярностью.
# •	Европейские пользователи также предпочитают динамичные жанры, такие как шутеры и экшены. Платформа PS3 занимает значительную долю рынка. Взрослые игры популярны, но игры для всех возрастов также имеют значительную аудиторию.
# •	В Японии пользователи предпочитают жанры ролевых игр и экшенов. Платформа DS доминирует на рынке. Игры для подростков с рейтингом "T" наиболее популярны, что может быть связано с культурными особенностями и предпочтениями японских игроков.
#
# 5. Проверка гипотез
# Были проверены следующие гипотезы:
#
# Гипотеза 1: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# Для гипотезы о равенстве средних пользовательских рейтингов платформ Xbox One и PC, p-значение оказалось значительно выше порогового уровня значимости (0.05), что не позволило отвергнуть нулевую гипотезу. Это означает, что у нас нет статистически значимых доказательств того, что пользовательские рейтинги на этих платформах различаются.
#
# Гипотеза 2: Средние пользовательские рейтинги жанров Action и Sports разные.
# Для гипотезы о равенстве средних пользовательских рейтингов жанров Action и Sports, p-значение оказалось значительно ниже порогового уровня значимости (0.05), что позволило отвергнуть нулевую гипотезу. Это указывает на то, что средние пользовательские рейтинги жанров Action и Sports статистически значимо различаются.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно обновить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках
#
#         В Северной Америке пользователи предпочитают динамичные и интенсивные игры, такие как шутеры и экшены. Они часто выбирают платформы X360 и PS3.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#
#  + выполнить проверку на дублирование записей
#  + самое важное — переопределить актуальный период
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5 и пересмотреть раздел рейтингов
#  + в разделе проверки гипотез подправить выборки плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)

# %% [markdown]
# ### Бонус

# %%
import numpy as np

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие

# функция не работает на версии библиотеки pandas >= 2.0 (метод .append устарел)

def graph (df, year, region, name, axes):
    
# фильтруем выборку по переменной

    df = df.query('year_of_release >= @year')

# собираем ТОП-5

    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()

# добавляем 6-ю категорию в ТОП-5

    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
# меняем названия колонок, но неоптимальным способом 🤝

    sales.columns = ['platform', 'sales']

# создаем словарь цветов    
# Цветовая гамма не подбиралась специально под платформы, кому-что попадется, 😉 
      
    labels_c=sales.platform
    colours = {'Wii':'C60', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'lightsteelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'Fuchsia', '2600':'C15', 'PSP':'C48', 
               'XOne':'LimeGreen',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
# рисуем графики

    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
# устанавливаем границы для графиков, чтобы не перекрывали друг друга
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2010

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд

x_year = 2013

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит обратить внимание на словарь цветов, когда на любом графике каждая платформа имеет свой цвет

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Я выбрал неудачный цвет для категории — «Другие», на темном фоне не видно цифры 😉
